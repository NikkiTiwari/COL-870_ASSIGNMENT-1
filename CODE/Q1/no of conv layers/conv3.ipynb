# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !unzip '/content/gdrive/MyDrive/2.zip'
# extracts the files on colab virtual machine
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: 1/train/bird/emu_s_000219.png
#  extracting: 1/train/bird/pipit_s_000192.png
#  extracting: 1/train/bird/flightless_bird_s_000562.png
#  extracting: 1/train/bird/passerine_s_001221.png
#  extracting: 1/train/bird/struthio_camelus_s_000008.png
#   inflating: 1/train/bird/pipit_s_000221.png
#  extracting: 1/train/bird/passerine_s_001226.png
#  extracting: 1/train/bird/emu_s_001158.png
#  extracting: 1/train/bird/accentor_s_000039.png
#  extracting: 1/train/bird/pipit_s_000029.png
#  extracting: 1/train/bird/ostrich_s_002262.png
#  extracting: 1/train/bird/struthio_camelus_s_000156.png
#   inflating: 1/train/bird/flightless_bird_s_000353.png
#  extracting: 1/train/bird/pipit_s_000443.png
#  extracting: 1/train/bird/ostrich_s_000506.png
#   inflating: 1/train/bird/sparrow_s_000490.png
#   inflating: 1/train/bird/ostrich_s_002057.png
#   inflating: 1/train/bird/meadow_pipit_s_000610.png
#  extracting: 1/train/bird/cassowary_s_001833.png
#  extracting: 1/train/bird/flying_bird_s_000775.png
#   inflating: 1/train/bird/dunnock_s_001078.png
#   inflating: 1/train/bird/emu_s_000258.png
#  extracting: 1/train/bird/dunnock_s_000507.png
#  extracting: 1/train/bird/passerine_s_000671.png
#   inflating: 1/train/bird/flightless_bird_s_000058.png
#   inflating: 1/train/bird/cassowary_s_000208.png
#   inflating: 1/train/bird/cassowary_s_000113.png
#  extracting: 1/train/bird/ratite_s_000229.png
#  extracting: 1/train/bird/pipit_s_000417.png
#   inflating: 1/train/bird/lark_s_000225.png
#  extracting: 1/train/bird/anthus_pratensis_s_000794.png
#   inflating: 1/train/bird/emu_s_002384.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000847.png
#  extracting: 1/train/bird/bird_s_001956.png
#  extracting: 1/train/bird/ostrich_s_000512.png
#  extracting: 1/train/bird/passerine_s_001633.png
#  extracting: 1/train/bird/anthus_pratensis_s_000285.png
#   inflating: 1/train/bird/sparrow_s_000167.png
#  extracting: 1/train/bird/sparrow_s_000969.png
#  extracting: 1/train/bird/sparrow_s_000812.png
#  extracting: 1/train/bird/ostrich_s_001744.png
#  extracting: 1/train/bird/dunnock_s_001466.png
#   inflating: 1/train/bird/bird_s_000305.png
#  extracting: 1/train/bird/dunnock_s_000226.png
#  extracting: 1/train/bird/sparrow_s_000098.png
#  extracting: 1/train/bird/honey_eater_s_000556.png
#  extracting: 1/train/bird/meadow_pipit_s_001282.png
#  extracting: 1/train/bird/rhea_americana_s_000481.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000188.png
#  extracting: 1/train/bird/prunella_modularis_s_000409.png
#  extracting: 1/train/bird/accentor_s_000087.png
#  extracting: 1/train/bird/cassowary_s_000497.png
#  extracting: 1/train/bird/struthio_camelus_s_000941.png
#  extracting: 1/train/bird/passerine_s_000287.png
#   inflating: 1/train/bird/ostrich_s_000723.png
#   inflating: 1/train/bird/bird_of_passage_s_000645.png
#  extracting: 1/train/bird/sparrow_s_000040.png
#   inflating: 1/train/bird/accentor_s_001026.png
#  extracting: 1/train/bird/pipit_s_001501.png
#   inflating: 1/train/bird/emu_s_001042.png
#  extracting: 1/train/bird/accentor_s_000813.png
#  extracting: 1/train/bird/dunnock_s_000832.png
#  extracting: 1/train/bird/finch_s_000779.png
#  extracting: 1/train/bird/songbird_s_002062.png
#  extracting: 1/train/bird/accentor_s_001241.png
#  extracting: 1/train/bird/struthio_camelus_s_001607.png
#  extracting: 1/train/bird/bird_s_001737.png
#  extracting: 1/train/bird/passerine_s_000249.png
#  extracting: 1/train/bird/finch_s_000326.png
#  extracting: 1/train/bird/bird_s_000220.png
#   inflating: 1/train/bird/ostrich_s_000062.png
#  extracting: 1/train/bird/sparrow_s_000715.png
#  extracting: 1/train/bird/sparrow_s_001750.png
#   inflating: 1/train/bird/finch_s_000750.png
#  extracting: 1/train/bird/dunnock_s_000411.png
#  extracting: 1/train/bird/rhea_americana_s_000080.png
#  extracting: 1/train/bird/rhea_americana_s_000270.png
#  extracting: 1/train/bird/emu_s_000700.png
#  extracting: 1/train/bird/prunella_modularis_s_000085.png
#  extracting: 1/train/bird/bird_s_000101.png
#  extracting: 1/train/bird/cassowary_s_001667.png
#  extracting: 1/train/bird/wagtail_s_001392.png
#  extracting: 1/train/bird/accentor_s_000884.png
#  extracting: 1/train/bird/songbird_s_001145.png
#  extracting: 1/train/bird/accentor_s_000537.png
#   inflating: 1/train/bird/cassowary_s_001258.png
#  extracting: 1/train/bird/prunella_modularis_s_000077.png
#  extracting: 1/train/bird/alauda_arvensis_s_000501.png
#  extracting: 1/train/bird/cassowary_s_001991.png
#  extracting: 1/train/bird/sparrow_s_002435.png
#  extracting: 1/train/bird/struthio_camelus_s_000395.png
#  extracting: 1/train/bird/oscine_s_000007.png
#  extracting: 1/train/bird/passerine_s_000343.png
#  extracting: 1/train/bird/anthus_pratensis_s_000812.png
#   inflating: 1/train/bird/sparrow_s_000707.png
#  extracting: 1/train/bird/passerine_s_000666.png
#  extracting: 1/train/bird/wagtail_s_000855.png
#   inflating: 1/train/bird/rhea_s_002272.png
#  extracting: 1/train/bird/meadow_pipit_s_000746.png
#  extracting: 1/train/bird/kiwi_s_000625.png
#  extracting: 1/train/bird/meadow_pipit_s_001438.png
#  extracting: 1/train/bird/struthio_camelus_s_001028.png
#  extracting: 1/train/bird/wagtail_s_001688.png
#  extracting: 1/train/bird/passerine_s_000281.png
#   inflating: 1/train/bird/wagtail_s_000207.png
#  extracting: 1/train/bird/struthio_camelus_s_001365.png
#  extracting: 1/train/bird/dunnock_s_000346.png
#  extracting: 1/train/bird/ostrich_s_001562.png
#  extracting: 1/train/bird/cassowary_s_000126.png
#   inflating: 1/train/bird/emu_s_001663.png
#  extracting: 1/train/bird/ostrich_s_000714.png
#  extracting: 1/train/bird/emu_s_000993.png
#  extracting: 1/train/bird/pipit_s_000050.png
#  extracting: 1/train/bird/ostrich_s_001567.png
#   inflating: 1/train/bird/bird_s_001864.png
#  extracting: 1/train/bird/prunella_modularis_s_000892.png
#   inflating: 1/train/bird/accentor_s_000521.png
#  extracting: 1/train/bird/wagtail_s_001430.png
#  extracting: 1/train/bird/dunnock_s_000356.png
#  extracting: 1/train/bird/honey_eater_s_001296.png
#  extracting: 1/train/bird/finch_s_000308.png
#  extracting: 1/train/bird/passerine_s_001676.png
#  extracting: 1/train/bird/meadow_pipit_s_001280.png
#  extracting: 1/train/bird/ostrich_s_000010.png
#  extracting: 1/train/bird/wagtail_s_000640.png
#  extracting: 1/train/bird/bird_s_001323.png
#  extracting: 1/train/bird/hedge_sparrow_s_000094.png
#  extracting: 1/train/bird/wagtail_s_001035.png
#  extracting: 1/train/bird/alauda_arvensis_s_001259.png
#   inflating: 1/train/bird/bird_of_passage_s_000214.png
#  extracting: 1/train/bird/sparrow_s_002671.png
#   inflating: 1/train/bird/bird_s_000126.png
#  extracting: 1/train/bird/honey_eater_s_000744.png
#  extracting: 1/train/bird/pipit_s_001116.png
#  extracting: 1/train/bird/finch_s_000130.png
#  extracting: 1/train/bird/prunella_modularis_s_000553.png
#  extracting: 1/train/bird/pipit_s_000206.png
#  extracting: 1/train/bird/passerine_s_001498.png
#  extracting: 1/train/bird/prunella_modularis_s_000314.png
#  extracting: 1/train/bird/bird_of_passage_s_000878.png
#  extracting: 1/train/bird/passerine_s_001603.png
#  extracting: 1/train/bird/bird_s_000207.png
#  extracting: 1/train/bird/alauda_arvensis_s_000090.png
#   inflating: 1/train/bird/lark_s_000703.png
#  extracting: 1/train/bird/cassowary_s_000472.png
#  extracting: 1/train/bird/honey_eater_s_000009.png
#  extracting: 1/train/bird/ostrich_s_001833.png
#   inflating: 1/train/bird/sparrow_s_001987.png
#  extracting: 1/train/bird/honey_eater_s_000002.png
#  extracting: 1/train/bird/alauda_arvensis_s_001222.png
#  extracting: 1/train/bird/bird_s_001268.png
#  extracting: 1/train/bird/sparrow_s_000979.png
#  extracting: 1/train/bird/hen_s_000014.png
#   inflating: 1/train/bird/prunella_modularis_s_000176.png
#  extracting: 1/train/bird/sparrow_s_002100.png
#   inflating: 1/train/bird/cassowary_s_000613.png
#  extracting: 1/train/bird/dunnock_s_000041.png
#  extracting: 1/train/bird/meadow_pipit_s_000472.png
#  extracting: 1/train/bird/finch_s_000197.png
#  extracting: 1/train/bird/bird_s_001625.png
#  extracting: 1/train/bird/lark_s_000693.png
#  extracting: 1/train/bird/sparrow_s_001159.png
#  extracting: 1/train/bird/pterocnemia_pennata_s_000093.png
#   inflating: 1/train/bird/lark_s_000310.png
#  extracting: 1/train/bird/alauda_arvensis_s_000486.png
#  extracting: 1/train/bird/nandu_s_001539.png
#  extracting: 1/train/bird/passerine_s_000350.png
#  extracting: 1/train/bird/flying_bird_s_000210.png
#  extracting: 1/train/bird/ostrich_s_001289.png
#  extracting: 1/train/bird/hen_s_000160.png
#   inflating: 1/train/bird/accentor_s_000967.png
#  extracting: 1/train/bird/lark_s_000331.png
#  extracting: 1/train/bird/wagtail_s_000942.png
#  extracting: 1/train/bird/lark_s_000002.png
#  extracting: 1/train/bird/struthio_camelus_s_001148.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000977.png
#  extracting: 1/train/bird/dunnock_s_000748.png
#   inflating: 1/train/bird/cassowary_s_002199.png
#  extracting: 1/train/bird/pterocnemia_pennata_s_000187.png
#  extracting: 1/train/bird/dunnock_s_000609.png
#   inflating: 1/train/bird/emu_s_000015.png
#  extracting: 1/train/bird/emu_s_001848.png
#  extracting: 1/train/bird/dunnock_s_001633.png
#  extracting: 1/train/bird/wagtail_s_001401.png
#  extracting: 1/train/bird/ostrich_s_000147.png
#  extracting: 1/train/bird/emu_s_000905.png
#   inflating: 1/train/bird/rhea_americana_s_000788.png
#  extracting: 1/train/bird/bird_s_001064.png
#  extracting: 1/train/bird/ostrich_s_001662.png
#  extracting: 1/train/bird/nandu_s_000697.png
#  extracting: 1/train/bird/wagtail_s_001362.png
#  extracting: 1/train/bird/ostrich_s_001663.png
#  extracting: 1/train/bird/accentor_s_000759.png
#  extracting: 1/train/bird/ostrich_s_001495.png
#   inflating: 1/train/bird/cassowary_s_000194.png
#  extracting: 1/train/bird/cassowary_s_001592.png
#   inflating: 1/train/bird/hen_s_000280.png
#   inflating: 1/train/bird/bird_s_000772.png
#   inflating: 1/train/bird/emu_s_002148.png
#  extracting: 1/train/bird/hen_s_000007.png
#  extracting: 1/train/bird/wagtail_s_000598.png
#   inflating: 1/train/bird/honey_eater_s_000903.png
#  extracting: 1/train/bird/cassowary_s_000118.png
#  extracting: 1/train/bird/accentor_s_001226.png
#  extracting: 1/train/bird/honey_eater_s_000740.png
#  extracting: 1/train/bird/cassowary_s_000694.png
#  extracting: 1/train/bird/sparrow_s_001924.png
#  extracting: 1/train/bird/pipit_s_001888.png
#  extracting: 1/train/bird/passerine_s_000628.png
#  extracting: 1/train/bird/pterocnemia_pennata_s_000058.png
#  extracting: 1/train/bird/cassowary_s_001875.png
#   inflating: 1/train/bird/sparrow_s_002493.png
#  extracting: 1/train/bird/struthio_camelus_s_000761.png
#   inflating: 1/train/bird/bird_s_002420.png
#  extracting: 1/train/bird/struthio_camelus_s_000536.png
#  extracting: 1/train/bird/cassowary_s_001492.png
#  extracting: 1/train/bird/struthio_camelus_s_000077.png
#  extracting: 1/train/bird/finch_s_000202.png
#   inflating: 1/train/bird/emu_s_002438.png
#   inflating: 1/train/bird/emu_novaehollandiae_s_000463.png
#   inflating: 1/train/bird/rhea_americana_s_000012.png
#  extracting: 1/train/bird/bird_s_000574.png
#   inflating: 1/train/bird/ostrich_s_002285.png
#  extracting: 1/train/bird/dunnock_s_000176.png
#  extracting: 1/train/bird/wagtail_s_000905.png
#  extracting: 1/train/bird/emu_novaehollandiae_s_000034.png
#  extracting: 1/train/bird/pipit_s_001409.png
#  extracting: 1/train/bird/nandu_s_001215.png
#  extracting: 1/train/bird/rhea_americana_s_000079.png
#   inflating: 1/train/bird/apteryx_s_000755.png
#   inflating: 1/train/bird/anthus_pratensis_s_000469.png
#  extracting: 1/train/bird/rhea_americana_s_000391.png
#  extracting: 1/train/bird/flying_bird_s_000583.png
#   inflating: 1/train/bird/honey_eater_s_000224.png
#  extracting: 1/train/bird/struthio_camelus_s_000147.png
#  extracting: 1/train/bird/wagtail_s_001045.png
#  extracting: 1/train/bird/honey_eater_s_001500.png
#  extracting: 1/train/bird/cassowary_s_001292.png
#  extracting: 1/train/bird/emu_s_001521.png
#  extracting: 1/train/bird/ostrich_s_000424.png
#   inflating: 1/train/bird/cassowary_s_002024.png
#  extracting: 1/train/bird/cassowary_s_002288.png
#  extracting: 1/train/bird/kiwi_s_001246.png
#  extracting: 1/train/bird/finch_s_000717.png
#  extracting: 1/train/bird/accentor_s_000740.png
#   inflating: 1/train/bird/alauda_arvensis_s_000047.png
#  extracting: 1/train/bird/ostrich_s_002460.png
#  extracting: 1/train/bird/cassowary_s_000865.png
#  extracting: 1/train/bird/cassowary_s_000218.png
#  extracting: 1/train/bird/nandu_s_000767.png
#  extracting: 1/train/bird/songbird_s_001329.png
#  extracting: 1/train/bird/ostrich_s_000782.png
#  extracting: 1/train/bird/wagtail_s_001937.png
#  extracting: 1/train/bird/night_bird_s_000253.png
#  extracting: 1/train/bird/cassowary_s_000801.png
#   inflating: 1/train/bird/ostrich_s_002118.png
#   inflating: 1/train/bird/cassowary_s_002365.png
#  extracting: 1/train/bird/sparrow_s_002220.png
#  extracting: 1/train/bird/accentor_s_000362.png
#  extracting: 1/train/bird/bird_s_002180.png
#  extracting: 1/train/bird/ostrich_s_001069.png
#  extracting: 1/train/bird/emu_s_000841.png
#  extracting: 1/train/bird/prunella_modularis_s_000564.png
#  extracting: 1/train/bird/nandu_s_001883.png
#   inflating: 1/train/bird/emu_s_001443.png
#  extracting: 1/train/bird/pipit_s_000320.png
#  extracting: 1/train/bird/alauda_arvensis_s_000105.png
#  extracting: 1/train/bird/struthio_camelus_s_000811.png
#  extracting: 1/train/bird/struthio_camelus_s_001637.png
#   inflating: 1/train/bird/accentor_s_000225.png
#  extracting: 1/train/bird/bird_s_001524.png
#  extracting: 1/train/bird/ostrich_s_002370.png
#  extracting: 1/train/bird/ostrich_s_000002.png
#   inflating: 1/train/bird/dromaius_novaehollandiae_s_000823.png
#  extracting: 1/train/bird/lark_s_001531.png
#  extracting: 1/train/bird/meadow_pipit_s_001074.png
#  extracting: 1/train/bird/gamecock_s_000026.png
#  extracting: 1/train/bird/cassowary_s_001567.png
#  extracting: 1/train/bird/pipit_s_000562.png
#  extracting: 1/train/bird/ostrich_s_001559.png
#  extracting: 1/train/bird/bird_s_000083.png
#   inflating: 1/train/bird/cassowary_s_001658.png
#  extracting: 1/train/bird/sparrow_s_000726.png
#  extracting: 1/train/bird/songbird_s_002056.png
#  extracting: 1/train/bird/bird_s_000050.png
#  extracting: 1/train/bird/honey_eater_s_000605.png
#  extracting: 1/train/bird/sparrow_s_001260.png
#  extracting: 1/train/bird/emu_novaehollandiae_s_000650.png
#   inflating: 1/train/bird/lark_s_001339.png
#  extracting: 1/train/bird/bird_s_001233.png
#   inflating: 1/train/bird/wagtail_s_001353.png
#  extracting: 1/train/bird/bird_s_001743.png
#  extracting: 1/train/bird/dunnock_s_000049.png
#  extracting: 1/train/bird/lark_s_000777.png
#  extracting: 1/train/bird/flightless_bird_s_000021.png
#  extracting: 1/train/bird/dunnock_s_000301.png
#  extracting: 1/train/bird/struthio_camelus_s_000857.png
#  extracting: 1/train/bird/rhea_americana_s_000134.png
#  extracting: 1/train/bird/bird_s_000996.png
#  extracting: 1/train/bird/ostrich_s_000473.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000978.png
#  extracting: 1/train/bird/wagtail_s_001305.png
#  extracting: 1/train/bird/alauda_arvensis_s_000166.png
#  extracting: 1/train/bird/cassowary_s_001783.png
#  extracting: 1/train/bird/bird_s_000773.png
#  extracting: 1/train/bird/emu_s_000251.png
#  extracting: 1/train/bird/honey_eater_s_000557.png
#  extracting: 1/train/bird/struthio_camelus_s_000493.png
#  extracting: 1/train/bird/rhea_americana_s_000202.png
#  extracting: 1/train/bird/ostrich_s_001050.png
#  extracting: 1/train/bird/wagtail_s_001880.png
#  extracting: 1/train/bird/ostrich_s_001142.png
#   inflating: 1/train/bird/meadow_pipit_s_001237.png
#  extracting: 1/train/bird/struthio_camelus_s_000334.png
#  extracting: 1/train/bird/cassowary_s_001017.png
#  extracting: 1/train/bird/pipit_s_000048.png
#  extracting: 1/train/bird/struthio_camelus_s_000793.png
#  extracting: 1/train/bird/songbird_s_001232.png
#  extracting: 1/train/bird/passerine_s_000278.png
#  extracting: 1/train/bird/flying_bird_s_001383.png
#  extracting: 1/train/bird/emu_s_001996.png
#  extracting: 1/train/bird/cassowary_s_002262.png
#  extracting: 1/train/bird/bird_s_002410.png
#  extracting: 1/train/bird/emu_novaehollandiae_s_000350.png
#  extracting: 1/train/bird/honey_eater_s_000983.png
#  extracting: 1/train/bird/struthio_camelus_s_000557.png
#  extracting: 1/train/bird/wagtail_s_001765.png
#  extracting: 1/train/bird/honey_eater_s_000696.png
#  extracting: 1/train/bird/emu_s_000747.png
#   inflating: 1/train/bird/cassowary_s_001956.png
#  extracting: 1/train/bird/struthio_camelus_s_000845.png
#  extracting: 1/train/bird/rhea_s_001189.png
#   inflating: 1/train/bird/dromaius_novaehollandiae_s_000037.png
#  extracting: 1/train/bird/passerine_s_000665.png
#  extracting: 1/train/bird/honey_eater_s_000033.png
#  extracting: 1/train/bird/wagtail_s_001046.png
#  extracting: 1/train/bird/cassowary_s_000708.png
#  extracting: 1/train/bird/ostrich_s_002425.png
#   inflating: 1/train/bird/sparrow_s_000018.png
#  extracting: 1/train/bird/bird_of_passage_s_000006.png
#  extracting: 1/train/bird/emu_s_002149.png
#  extracting: 1/train/bird/cassowary_s_001962.png
#  extracting: 1/train/bird/cassowary_s_002285.png
#  extracting: 1/train/bird/bird_s_000356.png
#  extracting: 1/train/bird/bird_s_001118.png
#   inflating: 1/train/bird/wagtail_s_001438.png
#  extracting: 1/train/bird/finch_s_000628.png
#  extracting: 1/train/bird/honey_eater_s_001161.png
#  extracting: 1/train/bird/accentor_s_000815.png
#  extracting: 1/train/bird/ostrich_s_001969.png
#  extracting: 1/train/bird/pipit_s_000121.png
#  extracting: 1/train/bird/sparrow_s_001199.png
#  extracting: 1/train/bird/dunnock_s_000031.png
#  extracting: 1/train/bird/flightless_bird_s_000652.png
#  extracting: 1/train/bird/wagtail_s_001732.png
#  extracting: 1/train/bird/sparrow_s_000176.png
#  extracting: 1/train/bird/alauda_arvensis_s_000153.png
#  extracting: 1/train/bird/bird_s_001427.png
#   inflating: 1/train/bird/ratite_bird_s_000040.png
#   inflating: 1/train/bird/cassowary_s_001477.png
#  extracting: 1/train/bird/alauda_arvensis_s_000064.png
#  extracting: 1/train/bird/honey_eater_s_000571.png
#  extracting: 1/train/bird/emu_s_000659.png
#  extracting: 1/train/bird/wagtail_s_001522.png
#   inflating: 1/train/bird/anthus_pratensis_s_001071.png
#  extracting: 1/train/bird/struthio_camelus_s_000745.png
#  extracting: 1/train/bird/rhea_s_000034.png
#  extracting: 1/train/bird/cassowary_s_001466.png
#  extracting: 1/train/bird/pipit_s_000217.png
#   inflating: 1/train/bird/apteryx_s_000233.png
#  extracting: 1/train/bird/passerine_s_000377.png
#  extracting: 1/train/bird/meadow_pipit_s_000067.png
#   inflating: 1/train/bird/accentor_s_000063.png
#  extracting: 1/train/bird/struthio_camelus_s_000065.png
#  extracting: 1/train/bird/prunella_modularis_s_000411.png
#  extracting: 1/train/bird/bird_of_passage_s_000597.png
#   inflating: 1/train/bird/ratite_s_000213.png
#   inflating: 1/train/bird/emu_s_001096.png
#  extracting: 1/train/bird/lark_s_001345.png
#  extracting: 1/train/bird/anthus_pratensis_s_001165.png
#  extracting: 1/train/bird/sparrow_s_000957.png
#  extracting: 1/train/bird/apteryx_s_000867.png
#  extracting: 1/train/bird/pipit_s_001502.png
#   inflating: 1/train/bird/emu_novaehollandiae_s_000859.png
#  extracting: 1/train/bird/cassowary_s_000264.png
#  extracting: 1/train/bird/bird_s_001031.png
#  extracting: 1/train/bird/bird_s_001113.png
#  extracting: 1/train/bird/elephant_bird_s_000396.png
#   inflating: 1/train/bird/emu_novaehollandiae_s_000549.png
#   inflating: 1/train/bird/ostrich_s_000939.png
#  extracting: 1/train/bird/hen_s_000059.png
#  extracting: 1/train/bird/struthio_camelus_s_000326.png
#  extracting: 1/train/bird/passerine_s_001130.png
#  extracting: 1/train/bird/cassowary_s_000747.png
#   inflating: 1/train/bird/dromaius_novaehollandiae_s_000039.png
#  extracting: 1/train/bird/passerine_s_001628.png
#  extracting: 1/train/bird/struthio_camelus_s_001164.png
#  extracting: 1/train/bird/nandu_s_000433.png
#  extracting: 1/train/bird/finch_s_000775.png
#  extracting: 1/train/bird/nandu_s_001688.png
#   inflating: 1/train/bird/sparrow_s_001699.png
#  extracting: 1/train/bird/songbird_s_001109.png
#  extracting: 1/train/bird/flightless_bird_s_000594.png
#  extracting: 1/train/bird/sparrow_s_002005.png
#  extracting: 1/train/bird/finch_s_000138.png
#  extracting: 1/train/bird/flying_bird_s_001726.png
#  extracting: 1/train/bird/emu_s_002197.png
#  extracting: 1/train/bird/dunnock_s_000641.png
#   inflating: 1/train/bird/cassowary_s_001262.png
#  extracting: 1/train/bird/sparrow_s_002400.png
#   inflating: 1/train/bird/bird_s_001865.png
#  extracting: 1/train/bird/prunella_modularis_s_000157.png
#  extracting: 1/train/bird/pipit_s_000496.png
#  extracting: 1/train/bird/finch_s_000387.png
#   inflating: 1/train/bird/emu_s_000043.png
#  extracting: 1/train/bird/sparrow_s_000022.png
#  extracting: 1/train/bird/rhea_americana_s_000793.png
#   inflating: 1/train/bird/accentor_s_000202.png
#  extracting: 1/train/bird/pipit_s_000842.png
#   inflating: 1/train/bird/nandu_s_001643.png
#  extracting: 1/train/bird/emu_s_000990.png
#  extracting: 1/train/bird/sparrow_s_001962.png
#  extracting: 1/train/bird/honey_eater_s_000952.png
#   inflating: 1/train/bird/honey_eater_s_001147.png
#  extracting: 1/train/bird/emu_s_000558.png
#  extracting: 1/train/bird/sparrow_s_000177.png
#   inflating: 1/train/bird/accentor_s_001162.png
#  extracting: 1/train/bird/struthio_camelus_s_001054.png
#   inflating: 1/train/bird/hen_s_000455.png
#  extracting: 1/train/bird/night_bird_s_000055.png
#  extracting: 1/train/bird/ostrich_s_001150.png
#  extracting: 1/train/bird/dunnock_s_000598.png
#  extracting: 1/train/bird/accentor_s_000979.png
#  extracting: 1/train/bird/wagtail_s_000886.png
#  extracting: 1/train/bird/struthio_camelus_s_000403.png
#  extracting: 1/train/bird/lark_s_001170.png
#  extracting: 1/train/bird/passerine_s_001626.png
#  extracting: 1/train/bird/cassowary_s_002387.png
#   inflating: 1/train/bird/accentor_s_001134.png
#   inflating: 1/train/bird/nandu_s_000788.png
#  extracting: 1/train/bird/lark_s_001917.png
#  extracting: 1/train/bird/honey_eater_s_001291.png
#  extracting: 1/train/bird/accentor_s_000425.png
#  extracting: 1/train/bird/pipit_s_001882.png
#  extracting: 1/train/bird/pipit_s_000850.png
#  extracting: 1/train/bird/rhea_americana_s_000406.png
#  extracting: 1/train/bird/sparrow_s_000239.png
#  extracting: 1/train/bird/cassowary_s_000593.png
#  extracting: 1/train/bird/accentor_s_001236.png
#  extracting: 1/train/bird/finch_s_000134.png
#   inflating: 1/train/bird/ostrich_s_001634.png
#  extracting: 1/train/bird/dunnock_s_000036.png
#   inflating: 1/train/bird/accentor_s_000845.png
#  extracting: 1/train/bird/cassowary_s_002283.png
#  extracting: 1/train/bird/passerine_s_000086.png
#  extracting: 1/train/bird/passerine_s_001454.png
#  extracting: 1/train/bird/wagtail_s_001307.png
#  extracting: 1/train/bird/honey_eater_s_000208.png
#   inflating: 1/train/bird/struthio_camelus_s_001702.png
#  extracting: 1/train/bird/cock_s_000155.png
#  extracting: 1/train/bird/cassowary_s_002187.png
#  extracting: 1/train/bird/pipit_s_001148.png
#  extracting: 1/train/bird/pipit_s_000122.png
#  extracting: 1/train/bird/struthio_camelus_s_000340.png
#   inflating: 1/train/bird/sparrow_s_001529.png
#  extracting: 1/train/bird/ostrich_s_000922.png
#  extracting: 1/train/bird/bird_s_000262.png
#  extracting: 1/train/bird/ostrich_s_002148.png
#  extracting: 1/train/bird/dunnock_s_000872.png
#   inflating: 1/train/bird/wagtail_s_000641.png
#  extracting: 1/train/bird/cock_s_000353.png
#  extracting: 1/train/bird/rhea_americana_s_000394.png
#  extracting: 1/train/bird/sparrow_s_001046.png
#   inflating: 1/train/bird/sparrow_s_002440.png
#   inflating: 1/train/bird/prunella_modularis_s_000037.png
#  extracting: 1/train/bird/dunnock_s_000358.png
#  extracting: 1/train/bird/sparrow_s_000011.png
#  extracting: 1/train/bird/struthio_camelus_s_000910.png
#  extracting: 1/train/bird/dunnock_s_001566.png
#   inflating: 1/train/bird/rhea_americana_s_000436.png
#  extracting: 1/train/bird/alauda_arvensis_s_000450.png
#  extracting: 1/train/bird/wagtail_s_001424.png
#  extracting: 1/train/bird/ostrich_s_001159.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000031.png
#   inflating: 1/train/bird/dunnock_s_001096.png
#   inflating: 1/train/bird/rhea_americana_s_000180.png
#  extracting: 1/train/bird/wagtail_s_002018.png
#  extracting: 1/train/bird/rhea_americana_s_000334.png
#  extracting: 1/train/bird/emu_novaehollandiae_s_000228.png
#  extracting: 1/train/bird/wagtail_s_001592.png
#  extracting: 1/train/bird/sparrow_s_000651.png
#  extracting: 1/train/bird/prunella_modularis_s_000618.png
#  extracting: 1/train/bird/struthio_camelus_s_000411.png
#  extracting: 1/train/bird/pipit_s_000985.png
#  extracting: 1/train/bird/passerine_s_000699.png
#  extracting: 1/train/bird/sparrow_s_002636.png
#  extracting: 1/train/bird/cassowary_s_001729.png
#   inflating: 1/train/bird/meadow_pipit_s_001310.png
#   inflating: 1/train/bird/pipit_s_000678.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000404.png
#  extracting: 1/train/bird/rhea_s_001418.png
#  extracting: 1/train/bird/pipit_s_000435.png
#   inflating: 1/train/bird/cassowary_s_000446.png
#  extracting: 1/train/bird/sparrow_s_000070.png
#  extracting: 1/train/bird/prunella_modularis_s_000719.png
#  extracting: 1/train/bird/passerine_s_000206.png
#   inflating: 1/train/bird/dromaius_novaehollandiae_s_000217.png
#  extracting: 1/train/bird/bird_s_001359.png
#  extracting: 1/train/bird/meadow_pipit_s_001371.png
#  extracting: 1/train/bird/bird_s_001650.png
#   inflating: 1/train/bird/nandu_s_001346.png
#  extracting: 1/train/bird/lark_s_000520.png
#  extracting: 1/train/bird/ostrich_s_000139.png
#  extracting: 1/train/bird/emu_s_001189.png
#  extracting: 1/train/bird/ostrich_s_000637.png
#  extracting: 1/train/bird/passerine_s_001235.png
#  extracting: 1/train/bird/alauda_arvensis_s_000784.png
#   inflating: 1/train/bird/struthio_camelus_s_000556.png
#  extracting: 1/train/bird/songbird_s_001479.png
#  extracting: 1/train/bird/emu_s_000263.png
#  extracting: 1/train/bird/emu_s_000274.png
#  extracting: 1/train/bird/sparrow_s_000623.png
#   inflating: 1/train/bird/prunella_modularis_s_000423.png
#  extracting: 1/train/bird/ostrich_s_001265.png
#  extracting: 1/train/bird/finch_s_000327.png
#  extracting: 1/train/bird/emu_novaehollandiae_s_000345.png
#   inflating: 1/train/bird/ostrich_s_001778.png
#  extracting: 1/train/bird/passerine_s_000766.png
#  extracting: 1/train/bird/hedge_sparrow_s_000232.png
#  extracting: 1/train/bird/honey_eater_s_000702.png
#  extracting: 1/train/bird/cassowary_s_001587.png
#  extracting: 1/train/bird/passerine_s_001679.png
#  extracting: 1/train/bird/anthus_pratensis_s_000819.png
#  extracting: 1/train/bird/accentor_s_000795.png
#  extracting: 1/train/bird/passerine_s_000286.png
#  extracting: 1/train/bird/honey_eater_s_001340.png
#  extracting: 1/train/bird/prunella_modularis_s_000222.png
#  extracting: 1/train/bird/wagtail_s_001539.png
#  extracting: 1/train/bird/sparrow_s_001226.png
#  extracting: 1/train/bird/rhea_s_002271.png
#  extracting: 1/train/bird/dunnock_s_000059.png
#  extracting: 1/train/bird/cassowary_s_001055.png
#  extracting: 1/train/bird/ostrich_s_000796.png
#  extracting: 1/train/bird/cassowary_s_000720.png
#   inflating: 1/train/bird/pipit_s_001448.png
#   inflating: 1/train/bird/cassowary_s_001323.png
#   inflating: 1/train/bird/meadow_pipit_s_000438.png
#  extracting: 1/train/bird/rhea_s_001558.png
#  extracting: 1/train/bird/honey_eater_s_000573.png
#   inflating: 1/train/bird/cassowary_s_002279.png
#  extracting: 1/train/bird/finch_s_000708.png
#  extracting: 1/train/bird/cassowary_s_000069.png
#  extracting: 1/train/bird/honey_eater_s_000785.png
#  extracting: 1/train/bird/cassowary_s_001273.png
#  extracting: 1/train/bird/bird_s_000137.png
#  extracting: 1/train/bird/lark_s_000170.png
#  extracting: 1/train/bird/prunella_modularis_s_000257.png
#   inflating: 1/train/bird/struthio_camelus_s_000013.png
#  extracting: 1/train/bird/wagtail_s_000028.png
#  extracting: 1/train/bird/cassowary_s_001992.png
#   inflating: 1/train/bird/emu_s_002336.png
#  extracting: 1/train/bird/cassowary_s_001167.png
#  extracting: 1/train/bird/bird_s_000142.png
#  extracting: 1/train/bird/pipit_s_000170.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000340.png
#  extracting: 1/train/bird/pipit_s_000691.png
#  extracting: 1/train/bird/wagtail_s_002104.png
#  extracting: 1/train/bird/bird_s_001452.png
#  extracting: 1/train/bird/cock_s_000336.png
#  extracting: 1/train/bird/honey_eater_s_001169.png
#  extracting: 1/train/bird/nandu_s_001449.png
#   inflating: 1/train/bird/struthio_camelus_s_001246.png
#  extracting: 1/train/bird/ostrich_s_001189.png
#  extracting: 1/train/bird/prunella_modularis_s_000860.png
#  extracting: 1/train/bird/bird_s_001337.png
#  extracting: 1/train/bird/ostrich_s_000111.png
#  extracting: 1/train/bird/cassowary_s_000309.png
#  extracting: 1/train/bird/ostrich_s_001569.png
#  extracting: 1/train/bird/skylark_s_001121.png
#  extracting: 1/train/bird/cassowary_s_002420.png
#  extracting: 1/train/bird/wagtail_s_000113.png
#  extracting: 1/train/bird/ostrich_s_002461.png
#  extracting: 1/train/bird/lark_s_002131.png
#  extracting: 1/train/bird/prunella_modularis_s_000068.png
#   inflating: 1/train/bird/accentor_s_000162.png
#  extracting: 1/train/bird/pipit_s_001907.png
#   inflating: 1/train/bird/cassowary_s_002399.png
#  extracting: 1/train/bird/emu_s_001134.png
#  extracting: 1/train/bird/emu_novaehollandiae_s_000006.png
#  extracting: 1/train/bird/emu_s_001887.png
#   inflating: 1/train/bird/wagtail_s_002090.png
#   inflating: 1/train/bird/accentor_s_000593.png
#  extracting: 1/train/bird/flying_bird_s_001425.png
#  extracting: 1/train/bird/alauda_arvensis_s_000433.png
#  extracting: 1/train/bird/accentor_s_001059.png
#  extracting: 1/train/bird/ostrich_s_000616.png
#  extracting: 1/train/bird/flying_bird_s_001380.png
#   inflating: 1/train/bird/wagtail_s_000481.png
#   inflating: 1/train/bird/cock_s_000285.png
#  extracting: 1/train/bird/finch_s_000704.png
#  extracting: 1/train/bird/wagtail_s_000459.png
#  extracting: 1/train/bird/emu_s_001904.png
#  extracting: 1/train/bird/cassowary_s_002429.png
#  extracting: 1/train/bird/pipit_s_000019.png
#  extracting: 1/train/bird/accentor_s_001206.png
#  extracting: 1/train/bird/passerine_s_001997.png
#  extracting: 1/train/bird/ostrich_s_000693.png
#  extracting: 1/train/bird/dunnock_s_000783.png
#  extracting: 1/train/bird/flying_bird_s_000606.png
#  extracting: 1/train/bird/bird_of_passage_s_000083.png
#   inflating: 1/train/bird/apteryx_s_000170.png
#  extracting: 1/train/bird/anthus_pratensis_s_001267.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000339.png
#  extracting: 1/train/bird/finch_s_000499.png
#  extracting: 1/train/bird/ostrich_s_001820.png
#   inflating: 1/train/bird/accentor_s_000314.png
#  extracting: 1/train/bird/sparrow_s_002450.png
#  extracting: 1/train/bird/passerine_s_000056.png
#  extracting: 1/train/bird/pipit_s_000184.png
#  extracting: 1/train/bird/nandu_s_001521.png
#  extracting: 1/train/bird/dunnock_s_000009.png
#  extracting: 1/train/bird/songbird_s_002059.png
#  extracting: 1/train/bird/wagtail_s_001724.png
#  extracting: 1/train/bird/wagtail_s_000289.png
#  extracting: 1/train/bird/bird_of_passage_s_000058.png
#   inflating: 1/train/bird/accentor_s_000287.png
#   inflating: 1/train/bird/dunnock_s_001127.png
#  extracting: 1/train/bird/flightless_bird_s_000560.png
#  extracting: 1/train/bird/cassowary_s_001496.png
#   inflating: 1/train/bird/cock_s_000399.png
#  extracting: 1/train/bird/ostrich_s_001955.png
#  extracting: 1/train/bird/pipit_s_001066.png
#  extracting: 1/train/bird/alauda_arvensis_s_000079.png
#   inflating: 1/train/bird/bird_of_passage_s_000190.png
#   inflating: 1/train/bird/bird_s_001240.png
#   inflating: 1/train/bird/emu_s_001500.png
#   inflating: 1/train/bird/wagtail_s_001039.png
#  extracting: 1/train/bird/anthus_pratensis_s_000930.png
#  extracting: 1/train/bird/honey_eater_s_000393.png
#  extracting: 1/train/bird/anthus_pratensis_s_000564.png
#  extracting: 1/train/bird/cassowary_s_001128.png
#  extracting: 1/train/bird/passerine_s_001460.png
#  extracting: 1/train/bird/cassowary_s_000339.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000631.png
#  extracting: 1/train/bird/ostrich_s_001245.png
#  extracting: 1/train/bird/meadow_pipit_s_001443.png
#  extracting: 1/train/bird/dunnock_s_001301.png
#  extracting: 1/train/bird/cassowary_s_000618.png
#  extracting: 1/train/bird/ostrich_s_000933.png
#   inflating: 1/train/bird/rhea_s_002151.png
#  extracting: 1/train/bird/passerine_s_001376.png
#  extracting: 1/train/bird/emu_s_000357.png
#  extracting: 1/train/bird/emu_s_001551.png
#   inflating: 1/train/bird/dunnock_s_000511.png
#  extracting: 1/train/bird/passerine_s_001365.png
#   inflating: 1/train/bird/bird_s_001491.png
#  extracting: 1/train/bird/sparrow_s_000811.png
#  extracting: 1/train/bird/bird_of_passage_s_000936.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000982.png
#  extracting: 1/train/bird/accentor_s_001106.png
#  extracting: 1/train/bird/honey_eater_s_001323.png
#  extracting: 1/train/bird/bird_s_001836.png
#  extracting: 1/train/bird/sparrow_s_001629.png
#   inflating: 1/train/bird/accentor_s_000538.png
#  extracting: 1/train/bird/passerine_s_000351.png
#  extracting: 1/train/bird/passerine_s_001938.png
#  extracting: 1/train/bird/wagtail_s_001421.png
#  extracting: 1/train/bird/accentor_s_000068.png
#  extracting: 1/train/bird/lark_s_001532.png
#   inflating: 1/train/bird/emu_s_000630.png
#   inflating: 1/train/bird/dromaius_novaehollandiae_s_000438.png
#  extracting: 1/train/bird/prunella_modularis_s_000787.png
#  extracting: 1/train/bird/pipit_s_000944.png
#   inflating: 1/train/bird/ostrich_s_000037.png
#   inflating: 1/train/bird/night_bird_s_000128.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000353.png
#  extracting: 1/train/bird/cassowary_s_002404.png
#  extracting: 1/train/bird/rhea_s_000559.png
#  extracting: 1/train/bird/emu_s_000396.png
#  extracting: 1/train/bird/ostrich_s_000344.png
#  extracting: 1/train/bird/alauda_arvensis_s_000456.png
#  extracting: 1/train/bird/wagtail_s_001881.png
#  extracting: 1/train/bird/sparrow_s_000015.png
#  extracting: 1/train/bird/songbird_s_001132.png
#  extracting: 1/train/bird/accentor_s_000807.png
#  extracting: 1/train/bird/ostrich_s_000872.png
#  extracting: 1/train/bird/sparrow_s_002612.png
#  extracting: 1/train/bird/nandu_s_001844.png
#  extracting: 1/train/bird/sparrow_s_001614.png
#  extracting: 1/train/bird/struthio_camelus_s_001307.png
#  extracting: 1/train/bird/bird_s_000768.png
#  extracting: 1/train/bird/cassowary_s_001842.png
#  extracting: 1/train/bird/flying_bird_s_001220.png
#   inflating: 1/train/bird/emu_s_001549.png
#  extracting: 1/train/bird/bird_of_passage_s_000258.png
#   inflating: 1/train/bird/nandu_s_000512.png
#   inflating: 1/train/bird/rhea_americana_s_000407.png
#  extracting: 1/train/bird/struthio_camelus_s_000171.png
#  extracting: 1/train/bird/passerine_s_000173.png
#  extracting: 1/train/bird/struthio_camelus_s_000351.png
#  extracting: 1/train/bird/finch_s_000336.png
#  extracting: 1/train/bird/meadow_pipit_s_000745.png
#  extracting: 1/train/bird/sparrow_s_002273.png
#   inflating: 1/train/bird/accentor_s_001003.png
#  extracting: 1/train/bird/anthus_pratensis_s_000371.png
#  extracting: 1/train/bird/cassowary_s_000004.png
#  extracting: 1/train/bird/wagtail_s_000510.png
#  extracting: 1/train/bird/passerine_s_001234.png
#  extracting: 1/train/bird/bird_s_001210.png
#  extracting: 1/train/bird/alauda_arvensis_s_000998.png
#  extracting: 1/train/bird/emu_s_001101.png
#  extracting: 1/train/bird/emu_s_001797.png
#  extracting: 1/train/bird/struthio_camelus_s_001559.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000400.png
#  extracting: 1/train/bird/wagtail_s_000097.png
#   inflating: 1/train/bird/bird_s_001360.png
#   inflating: 1/train/bird/accentor_s_000127.png
#  extracting: 1/train/bird/bird_s_001254.png
#  extracting: 1/train/bird/accentor_s_000462.png
#  extracting: 1/train/bird/finch_s_000299.png
#  extracting: 1/train/bird/passerine_s_001281.png
#  extracting: 1/train/bird/cassowary_s_000458.png
#  extracting: 1/train/bird/accentor_s_001098.png
#  extracting: 1/train/bird/dunnock_s_000841.png
#   inflating: 1/train/bird/cassowary_s_001290.png
#   inflating: 1/train/bird/wagtail_s_000149.png
#  extracting: 1/train/bird/sparrow_s_002001.png
#  extracting: 1/train/bird/emu_s_001160.png
#   inflating: 1/train/bird/ostrich_s_002372.png
#   inflating: 1/train/bird/lark_s_000413.png
#  extracting: 1/train/bird/ostrich_s_002038.png
#  extracting: 1/train/bird/sparrow_s_000851.png
#  extracting: 1/train/bird/cassowary_s_001065.png
#   inflating: 1/train/bird/rhea_americana_s_000695.png
#  extracting: 1/train/bird/emu_s_000540.png
#  extracting: 1/train/bird/bird_s_001828.png
#   inflating: 1/train/bird/pipit_s_000124.png
#   inflating: 1/train/bird/emu_novaehollandiae_s_000486.png
#  extracting: 1/train/bird/sparrow_s_001591.png
#  extracting: 1/train/bird/finch_s_000607.png
#   inflating: 1/train/bird/cassowary_s_001480.png
#  extracting: 1/train/bird/bird_s_000105.png
#  extracting: 1/train/bird/dromaius_novaehollandiae_s_000089.png
#  extracting: 1/train/bird/emu_s_000041.png
#   inflating: 1/train/bird/lark_s_000407.png
#  extracting: 1/train/bird/anthus_pratensis_s_000222.png
#   inflating: 1/train/bird/ostrich_s_000617.png
#  extracting: 1/train/bird/accentor_s_000019.png
#   inflating: 1/train/bird/apteryx_s_000607.png
#  extracting: 1/train/bird/accentor_s_000383.png
#  extracting: 1/train/bird/passerine_s_001466.png
#   inflating: 1/train/bird/bird_s_001444.png
#  extracting: 1/train/bird/wagtail_s_000823.png
#  extracting: 1/train/bird/pipit_s_001102.png
#  extracting: 1/train/bird/emu_novaehollandiae_s_000244.png
#  extracting: 1/train/bird/passerine_s_001139.png
#  extracting: 1/train/bird/passerine_s_001605.png
#   inflating: 1/train/bird/cassowary_s_000903.png
#   inflating: 1/train/bird/cassowary_s_002331.png
#  extracting: 1/train/bird/struthio_camelus_s_000407.png
#  extracting: 1/train/bird/cassowary_s_002076.png
#  extracting: 1/train/bird/wagtail_s_001526.png
#   inflating: 1/train/bird/hen_s_000401.png
#   inflating: 1/train/bird/rhea_americana_s_000077.png
#   inflating: 1/train/bird/emu_s_002236.png
#  extracting: 1/train/bird/rhea_americana_s_000766.png
#   inflating: 1/train/bird/accentor_s_001180.png
#  extracting: 1/train/bird/rhea_americana_s_000564.png
#  extracting: 1/train/bird/accentor_s_000142.png
#  extracting: 1/train/bird/bird_s_002101.png
#  extracting: 1/train/bird/wagtail_s_001706.png
#  extracting: 1/train/bird/finch_s_000759.png
#  extracting: 1/train/bird/pipit_s_000268.png
#   inflating: 1/train/bird/wagtail_s_001205.png
#  extracting: 1/train/bird/bird_s_000935.png
#  extracting: 1/train/bird/rhea_americana_s_000184.png
#   inflating: 1/train/bird/dunnock_s_001570.png
#   inflating: 1/train/bird/apteryx_s_000164.png
#  extracting: 1/train/bird/bird_s_000096.png
#  extracting: 1/train/bird/struthio_camelus_s_000035.png
#  extracting: 1/train/bird/skylark_s_000270.png
#  extracting: 1/train/bird/anthus_pratensis_s_000539.png
#  extracting: 1/train/bird/finch_s_000307.png
#   inflating: 1/train/bird/cock_s_000397.png
#   inflating: 1/train/bird/accentor_s_000545.png
#  extracting: 1/train/bird/accentor_s_000488.png
#  extracting: 1/train/bird/nandu_s_000396.png
#  extracting: 1/train/bird/sparrow_s_001269.png
#  extracting: 1/train/bird/meadow_pipit_s_000410.png
#  extracting: 1/train/bird/nandu_s_000265.png
#  extracting: 1/train/bird/cock_s_000403.png
#  extracting: 1/train/bird/passerine_s_001599.png
#  extracting: 1/train/bird/honey_eater_s_001427.png
#  extracting: 1/train/bird/bird_s_002178.png
#  extracting: 1/train/bird/struthio_camelus_s_000576.png
#  extracting: 1/train/bird/ostrich_s_001208.png
#  extracting: 1/train/bird/flying_bird_s_001743.png
#  extracting: 1/train/bird/alauda_arvensis_s_000138.png
#   inflating: 1/train/bird/honey_eater_s_001511.png
#   inflating: 1/train/bird/ostrich_s_000015.png
#   inflating: 1/train/bird/pipit_s_000126.png
#   inflating: 1/train/bird/ostrich_s_000934.png
#   inflating: 1/train/bird/cassowary_s_000221.png
#   inflating: 1/train/bird/honey_eater_s_000563.png
#  extracting: 1/train/bird/sparrow_s_002628.png
#  extracting: 1/train/bird/flying_bird_s_001737.png
#  extracting: 1/train/bird/alauda_arvensis_s_000960.png
#   inflating: 1/train/bird/sparrow_s_001651.png
#   inflating: 1/train/bird/emu_novaehollandiae_s_000375.png
#  extracting: 1/train/bird/accentor_s_000918.png
#  extracting: 1/train/bird/bird_s_001825.png
#  extracting: 1/train/bird/accentor_s_001115.png
#  extracting: 1/train/bird/bird_s_001066.png
#  extracting: 1/train/bird/ostrich_s_001565.png
#   inflating: 1/train/bird/bird_s_000727.png
#   inflating: 1/train/bird/struthio_camelus_s_000517.png
#  extracting: 1/train/bird/wagtail_s_000006.png
#  extracting: 1/train/bird/wagtail_s_000597.png
#  extracting: 1/train/bird/emu_s_001357.png
#  extracting: 1/train/bird/wagtail_s_002044.png
#  extracting: 1/train/bird/rhea_americana_s_000014.png
#  extracting: 1/train/bird/pipit_s_000865.png
#  extracting: 1/train/bird/alauda_arvensis_s_000585.png
#  extracting: 1/train/bird/struthio_camelus_s_001539.png
#  extracting: 1/train/bird/cassowary_s_000605.png
#   inflating: 1/train/bird/emu_s_000953.png
#  extracting: 1/train/bird/finch_s_000435.png
#  extracting: 1/train/bird/emu_s_002196.png
#  extracting: 1/train/bird/prunella_modularis_s_000174.png
#  extracting: 1/train/bird/honey_eater_s_001541.png
#  extracting: 1/train/bird/pipit_s_001637.png
#  extracting: 1/train/bird/pipit_s_000426.png
#   inflating: 1/train/bird/wagtail_s_001483.png
#  extracting: 1/train/bird/cassowary_s_001845.png
#  extracting: 1/train/bird/bird_s_001838.png
#  extracting: 1/train/bird/bird_s_000214.png
#  extracting: 1/train/bird/accentor_s_000198.png
#  extracting: 1/train/bird/bird_s_001231.png
#  extracting: 1/train/bird/meadow_pipit_s_000265.png
#  extracting: 1/train/bird/rhea_americana_s_000026.png
#  extracting: 1/train/bird/honey_eater_s_000036.png
#   inflating: 1/train/bird/apteryx_s_000304.png
#   inflating: 1/train/bird/emu_novaehollandiae_s_000145.png
#  extracting: 1/train/bird/pipit_s_001021.png
#  extracting: 1/train/bird/cassowary_s_000294.png
#  extracting: 1/train/bird/emu_s_001519.png
#   inflating: 1/train/bird/accentor_s_000951.png
#  extracting: 1/train/bird/wagtail_s_000128.png
#   inflating: 1/train/bird/rhea_americana_s_000078.png
#   inflating: 1/train/bird/emu_s_001910.png
#  extracting: 1/train/bird/struthio_camelus_s_001313.png
#  extracting: 1/train/bird/ostrich_s_002279.png
#  extracting: 1/train/bird/cassowary_s_000921.png
#   inflating: 1/train/bird/bird_of_passage_s_000253.png
#  extracting: 1/train/bird/accentor_s_000439.png
#  extracting: 1/train/bird/prunella_modularis_s_000655.png
#  extracting: 1/train/bird/dunnock_s_000151.png
#  extracting: 1/train/bird/ostrich_s_001523.png
#  extracting: 1/train/bird/struthio_camelus_s_000889.png
#  extracting: 1/train/bird/ostrich_s_002359.png
#  extracting: 1/train/bird/bird_s_000785.png
#  extracting: 1/train/bird/accentor_s_001217.png
#   inflating: 1/train/bird/alauda_arvensis_s_001275.png
#  extracting: 1/train/bird/alauda_arvensis_s_000120.png
#  extracting: 1/train/bird/cassowary_s_002083.png
#  extracting: 1/train/bird/flying_bird_s_001055.png
#  extracting: 1/train/bird/wagtail_s_002096.png
#  extracting: 1/train/bird/alauda_arvensis_s_000667.png
#  extracting: 1/train/bird/emu_novaehollandiae_s_000795.png
#  extracting: 1/train/bird/pipit_s_001421.png
#  extracting: 1/train/bird/struthio_camelus_s_001682.png
#   inflating: 1/train/bird/rhea_americana_s_000261.png
#   inflating: 1/train/bird/ostrich_s_002247.png
#  extracting: 1/train/bird/struthio_camelus_s_000479.png
#  extracting: 1/train/bird/sparrow_s_002574.png
#  extracting: 1/train/bird/passerine_s_000167.png
#  extracting: 1/train/bird/meadow_pipit_s_000464.png
#  extracting: 1/train/bird/sparrow_s_002531.png
#  extracting: 1/train/bird/bird_s_001560.png
#  extracting: 1/train/bird/nandu_s_002091.png
#  extracting: 1/train/bird/passerine_s_001611.png
#  extracting: 1/train/bird/cassowary_s_000276.png
#  extracting: 1/train/bird/pipit_s_000017.png
#  extracting: 1/train/bird/bird_s_000463.png
#   inflating: 1/train/bird/cassowary_s_001136.png
#  extracting: 1/train/bird/rhea_americana_s_000535.png
#  extracting: 1/train/bird/cassowary_s_000338.png
#  extracting: 1/train/bird/sparrow_s_000394.png
#  extracting: 1/train/bird/wagtail_s_000131.png
#  extracting: 1/train/bird/bird_s_002274.png
#   inflating: 1/train/bird/rhea_americana_s_000808.png
#  extracting: 1/train/bird/bird_s_002322.png
#   inflating: 1/train/bird/rhea_americana_s_000792.png
#  extracting: 1/train/bird/emu_s_000388.png
#   inflating: 1/train/bird/kiwi_s_000003.png
#  extracting: 1/train/bird/hedge_sparrow_s_000165.png
#  extracting: 1/train/bird/struthio_camelus_s_000146.png
#  extracting: 1/train/bird/cassowary_s_002155.png
#  extracting: 1/train/bird/emu_s_002282.png
#  extracting: 1/train/bird/bird_s_000836.png
#  extracting: 1/train/bird/honey_eater_s_001325.png
#  extracting: 1/train/bird/lark_s_001929.png
#  extracting: 1/train/bird/finch_s_000011.png
#  extracting: 1/train/bird/emu_s_000177.png
#  extracting: 1/train/bird/ostrich_s_002274.png
#  extracting: 1/train/bird/passerine_s_001103.png
#  extracting: 1/train/bird/ostrich_s_001022.png
#  extracting: 1/train/bird/pipit_s_000364.png
#  extracting: 1/train/bird/emu_s_001488.png
#  extracting: 1/train/bird/ratite_s_000198.png
#   inflating: 1/train/bird/hedge_sparrow_s_000007.png
#  extracting: 1/train/bird/bird_s_000311.png
#   inflating: 1/train/bird/rhea_americana_s_000649.png
#  extracting: 1/train/bird/ratite_s_000205.png
#   inflating: 1/train/bird/night_bird_s_000142.png
#  extracting: 1/train/bird/wagtail_s_002001.png
#   inflating: 1/train/bird/wagtail_s_001520.png
#  extracting: 1/train/bird/struthio_camelus_s_001224.png
#  extracting: 1/train/bird/ostrich_s_001669.png
#  extracting: 1/train/bird/bird_s_001527.png
#  extracting: 1/train/bird/nandu_s_000040.png
#  extracting: 1/train/bird/struthio_camelus_s_000387.png
#   inflating: 1/train/bird/cassowary_s_001194.png
#   inflating: 1/train/bird/wagtail_s_002108.png
#  extracting: 1/train/bird/bird_s_001157.png
#  extracting: 1/train/bird/sparrow_s_000466.png
#   inflating: 1/train/bird/ostrich_s_002351.png
#  extracting: 1/train/bird/bird_s_001712.png
#  extracting: 1/train/bird/sparrow_s_001257.png
#  extracting: 1/train/bird/bird_s_002415.png
#  extracting: 1/train/bird/emu_s_002188.png
#  extracting: 1/train/bird/accentor_s_000963.png
#  extracting: 1/train/bird/honey_eater_s_001068.png
#  extracting: 1/train/bird/nandu_s_001607.png
#   inflating: 1/train/bird/emu_s_002482.png
#  extracting: 1/train/bird/ostrich_s_000005.png
#  extracting: 1/train/bird/accentor_s_000924.png
#  extracting: 1/train/bird/cassowary_s_001157.png
#  extracting: 1/train/bird/pipit_s_000260.png
#  extracting: 1/train/bird/cassowary_s_000511.png
#  extracting: 1/train/bird/pipit_s_001523.png
#  extracting: 1/train/bird/cassowary_s_001490.png
#   inflating: 1/train/bird/struthio_camelus_s_001213.png
# ...
#  extracting: 1/test/bird/hedge_sparrow_s_000130.png
#  extracting: 1/test/bird/struthio_camelus_s_000865.png
#  extracting: 1/test/bird/sparrow_s_001664.png
#   inflating: 1/test/bird/bird_s_001353.png
#  extracting: 1/test/bird/flying_bird_s_001013.png
#  extracting: 1/test/bird/bird_s_001522.png
#  extracting: 1/test/bird/struthio_camelus_s_000948.png
#   inflating: 1/test/bird/accentor_s_000293.png
#  extracting: 1/test/bird/anthus_pratensis_s_000502.png
#  extracting: 1/test/bird/wagtail_s_000932.png
#  extracting: 1/test/bird/prunella_modularis_s_000419.png
#  extracting: 1/test/bird/cassowary_s_000028.png
#  extracting: 1/test/bird/finch_s_000467.png
#  extracting: 1/test/bird/bird_of_passage_s_000427.png
#   inflating: 1/test/bird/alauda_arvensis_s_000559.png
#   inflating: 1/test/bird/accentor_s_000102.png
#   inflating: 1/test/bird/emu_s_002040.png
#  extracting: 1/test/bird/emu_s_001990.png
#  extracting: 1/test/bird/songbird_s_001048.png
#   inflating: 1/test/bird/emu_s_002345.png
#   inflating: 1/test/bird/skylark_s_001801.png
#  extracting: 1/test/bird/passerine_s_000369.png
#  extracting: 1/test/bird/songbird_s_001995.png
#  extracting: 1/test/bird/bird_s_001097.png
#  extracting: 1/test/bird/flying_bird_s_000012.png
#  extracting: 1/test/bird/passerine_s_000144.png
#  extracting: 1/test/bird/pipit_s_000362.png
#  extracting: 1/test/bird/nandu_s_000003.png
#   inflating: 1/test/bird/ostrich_s_001319.png
#  extracting: 1/test/bird/rhea_americana_s_000727.png
#  extracting: 1/test/bird/passerine_s_001401.png
#  extracting: 1/test/bird/accentor_s_001124.png
#   inflating: 1/test/bird/flying_bird_s_001738.png
#  extracting: 1/test/bird/honey_eater_s_001132.png
#  extracting: 1/test/bird/ostrich_s_001428.png
#  extracting: 1/test/bird/cassowary_s_001050.png
#  extracting: 1/test/bird/anthus_pratensis_s_000568.png
#  extracting: 1/test/bird/skylark_s_001741.png
#  extracting: 1/test/bird/nandu_s_000234.png
#  extracting: 1/test/bird/accentor_s_000774.png
#  extracting: 1/test/bird/sparrow_s_001661.png
#   inflating: 1/test/bird/honey_eater_s_001255.png
#  extracting: 1/test/bird/passerine_s_001359.png
#  extracting: 1/test/bird/flying_bird_s_001998.png
#  extracting: 1/test/bird/passerine_s_000171.png
#  extracting: 1/test/bird/rhea_americana_s_000730.png
#  extracting: 1/test/bird/lark_s_000489.png
#  extracting: 1/test/bird/wagtail_s_001764.png
#  extracting: 1/test/bird/alauda_arvensis_s_000891.png
#  extracting: 1/test/bird/passerine_s_000299.png
#  extracting: 1/test/bird/pipit_s_000439.png
#  extracting: 1/test/bird/bird_s_000953.png
#   inflating: 1/test/bird/nandu_s_001661.png
#   inflating: 1/test/bird/wagtail_s_002032.png
#  extracting: 1/test/bird/cock_s_000143.png
#  extracting: 1/test/bird/flightless_bird_s_000259.png
#  extracting: 1/test/bird/bird_of_passage_s_000119.png
#  extracting: 1/test/bird/ostrich_s_000508.png
#  extracting: 1/test/bird/ostrich_s_000517.png
#  extracting: 1/test/bird/alauda_arvensis_s_000089.png
#   inflating: 1/test/bird/passerine_s_001581.png
#  extracting: 1/test/bird/passerine_s_000759.png
#  extracting: 1/test/bird/dunnock_s_000063.png
#  extracting: 1/test/bird/honey_eater_s_000421.png
#  extracting: 1/test/bird/passerine_s_000755.png
#   inflating: 1/test/bird/cassowary_s_001156.png
#  extracting: 1/test/bird/ostrich_s_000212.png
#  extracting: 1/test/bird/sparrow_s_002410.png
#   inflating: 1/test/bird/wagtail_s_000408.png
#   inflating: 1/test/bird/nandu_s_001188.png
#  extracting: 1/test/bird/bird_s_000613.png
#   inflating: 1/test/bird/struthio_camelus_s_000887.png
#  extracting: 1/test/bird/honey_eater_s_000351.png
#  extracting: 1/test/bird/hedge_sparrow_s_000182.png
#   inflating: 1/test/bird/carinate_s_000166.png
#   inflating: 1/test/bird/pipit_s_000003.png
#  extracting: 1/test/bird/emu_s_000246.png
#  extracting: 1/test/bird/wagtail_s_000646.png
#  extracting: 1/test/bird/ostrich_s_001597.png
#  extracting: 1/test/bird/rhea_s_001591.png
#  extracting: 1/test/bird/sparrow_s_002280.png
#  extracting: 1/test/bird/emu_s_001889.png
#   inflating: 1/test/bird/wagtail_s_001810.png
#   inflating: 1/test/bird/sparrow_s_001583.png
#  extracting: 1/test/bird/alauda_arvensis_s_000789.png
#  extracting: 1/test/bird/sparrow_s_000281.png
#  extracting: 1/test/bird/pipit_s_000399.png
#  extracting: 1/test/bird/bird_s_002333.png
#  extracting: 1/test/bird/bird_s_001914.png
#  extracting: 1/test/bird/pipit_s_000852.png
#  extracting: 1/test/bird/flying_bird_s_001209.png
#  extracting: 1/test/bird/wagtail_s_000924.png
#  extracting: 1/test/bird/meadow_pipit_s_001447.png
#  extracting: 1/test/bird/flightless_bird_s_000136.png
#  extracting: 1/test/bird/bird_s_000065.png
#   inflating: 1/test/bird/wagtail_s_002060.png
#   inflating: 1/test/bird/finch_s_000254.png
#  extracting: 1/test/bird/ostrich_s_001507.png
#  extracting: 1/test/bird/cassowary_s_000881.png
#   inflating: 1/test/bird/passerine_s_001213.png
#  extracting: 1/test/bird/wagtail_s_000519.png
#  extracting: 1/test/bird/wagtail_s_000639.png
#  extracting: 1/test/bird/flying_bird_s_000002.png
#  extracting: 1/test/bird/alauda_arvensis_s_000106.png
#  extracting: 1/test/bird/sparrow_s_001051.png
#  extracting: 1/test/bird/cassowary_s_002362.png
#  extracting: 1/test/bird/wagtail_s_001686.png
#  extracting: 1/test/bird/alauda_arvensis_s_000744.png
#  extracting: 1/test/bird/bird_s_001448.png
#  extracting: 1/test/bird/honey_eater_s_001093.png
#  extracting: 1/test/bird/bird_s_001352.png
#   inflating: 1/test/bird/prunella_modularis_s_000183.png
#  extracting: 1/test/bird/ratite_s_000179.png
#   inflating: 1/test/bird/ostrich_s_002602.png
#  extracting: 1/test/bird/prunella_modularis_s_000881.png
#  extracting: 1/test/bird/bird_s_001910.png
#  extracting: 1/test/bird/passerine_s_000664.png
#  extracting: 1/test/bird/rhea_americana_s_000028.png
#  extracting: 1/test/bird/passerine_s_000378.png
#   inflating: 1/test/bird/sparrow_s_000114.png
#  extracting: 1/test/bird/hen_s_000234.png
#  extracting: 1/test/bird/dunnock_s_001008.png
#   inflating: 1/test/bird/sparrow_s_000867.png
#  extracting: 1/test/bird/finch_s_000096.png
#  extracting: 1/test/bird/finch_s_000376.png
#  extracting: 1/test/bird/ostrich_s_000024.png
#  extracting: 1/test/bird/bird_s_001330.png
#  extracting: 1/test/bird/struthio_camelus_s_000656.png
#  extracting: 1/test/bird/finch_s_000792.png
#  extracting: 1/test/bird/honey_eater_s_000542.png
#  extracting: 1/test/bird/wagtail_s_000804.png
#   inflating: 1/test/bird/bird_s_001733.png
#  extracting: 1/test/bird/pipit_s_001542.png
#  extracting: 1/test/bird/songbird_s_002057.png
#  extracting: 1/test/bird/struthio_camelus_s_000917.png
#   inflating: 1/test/bird/ostrich_s_002266.png
#  extracting: 1/test/bird/dunnock_s_001089.png
#  extracting: 1/test/bird/honey_eater_s_000591.png
#  extracting: 1/test/bird/pipit_s_001095.png
#  extracting: 1/test/bird/dunnock_s_001203.png
#   inflating: 1/test/bird/emu_s_002027.png
#  extracting: 1/test/bird/passerine_s_000477.png
#  extracting: 1/test/bird/accentor_s_000825.png
#   inflating: 1/test/bird/nandu_s_000986.png
#  extracting: 1/test/bird/flying_bird_s_001895.png
#  extracting: 1/test/bird/emu_s_000690.png
#  extracting: 1/test/bird/meadow_pipit_s_000371.png
#  extracting: 1/test/bird/bird_s_002116.png
#   inflating: 1/test/bird/sparrow_s_002465.png
#   inflating: 1/test/bird/finch_s_000542.png
#  extracting: 1/test/bird/flightless_bird_s_000241.png
#  extracting: 1/test/bird/rhea_americana_s_000248.png
#   inflating: 1/test/bird/emu_novaehollandiae_s_000563.png
#   inflating: 1/test/bird/ostrich_s_000098.png
#  extracting: 1/test/bird/rhea_s_000854.png
#  extracting: 1/test/bird/bird_s_001419.png
#  extracting: 1/test/bird/sparrow_s_001712.png
#  extracting: 1/test/bird/emu_s_002009.png
#  extracting: 1/test/bird/wagtail_s_001743.png
#  extracting: 1/test/bird/bird_s_000975.png
#  extracting: 1/test/bird/sparrow_s_001232.png
#   inflating: 1/test/bird/ostrich_s_001423.png
#  extracting: 1/test/bird/prunella_modularis_s_000264.png
#  extracting: 1/test/bird/ratite_s_000052.png
#  extracting: 1/test/bird/passerine_s_001817.png
#  extracting: 1/test/bird/sparrow_s_000033.png
#  extracting: 1/test/bird/sparrow_s_001617.png
#  extracting: 1/test/bird/finch_s_000606.png
#  extracting: 1/test/bird/rhea_s_000225.png
#  extracting: 1/test/bird/nandu_s_001782.png
#  extracting: 1/test/bird/night_bird_s_000069.png
#   inflating: 1/test/bird/nandu_s_001738.png
#  extracting: 1/test/bird/struthio_camelus_s_001609.png
#  extracting: 1/test/bird/prunella_modularis_s_000516.png
#  extracting: 1/test/bird/pipit_s_000289.png
#  extracting: 1/test/bird/bird_of_passage_s_000323.png
#  extracting: 1/test/bird/passerine_s_001158.png
#   inflating: 1/test/bird/cassowary_s_001355.png
#   inflating: 1/test/bird/emu_s_000384.png
#  extracting: 1/test/bird/sparrow_s_000119.png
#  extracting: 1/test/bird/struthio_camelus_s_000706.png
#  extracting: 1/test/bird/wagtail_s_002019.png
#  extracting: 1/test/bird/meadow_pipit_s_000071.png
#  extracting: 1/test/bird/ostrich_s_001473.png
#  extracting: 1/test/bird/songbird_s_000715.png
#   inflating: 1/test/bird/emu_s_001695.png
#  extracting: 1/test/bird/lark_s_001440.png
#   inflating: 1/test/bird/sparrow_s_000158.png
#   inflating: 1/test/bird/bird_s_001476.png
#   inflating: 1/test/bird/cassowary_s_001106.png
#  extracting: 1/test/bird/cassowary_s_001776.png
#  extracting: 1/test/bird/pipit_s_000291.png
#  extracting: 1/test/bird/aepyornis_s_000432.png
#  extracting: 1/test/bird/prunella_modularis_s_000006.png
#   inflating: 1/test/bird/prunella_modularis_s_000008.png
#   inflating: 1/test/bird/sparrow_s_001322.png
#  extracting: 1/test/bird/accentor_s_000824.png
#  extracting: 1/test/bird/pipit_s_000433.png
#  extracting: 1/test/bird/fighting_cock_s_000026.png
#  extracting: 1/test/bird/rhea_americana_s_000037.png
#  extracting: 1/test/bird/wagtail_s_001109.png
#  extracting: 1/test/bird/passerine_s_000947.png
#  extracting: 1/test/bird/ostrich_s_002358.png
#  extracting: 1/test/bird/alauda_arvensis_s_000753.png
#   inflating: 1/test/bird/bird_s_000669.png
#  extracting: 1/test/bird/struthio_camelus_s_000463.png
#   inflating: 1/test/bird/honey_eater_s_000870.png
#   inflating: 1/test/bird/struthio_camelus_s_000020.png
#  extracting: 1/test/bird/sparrow_s_001460.png
#   inflating: 1/test/bird/cassowary_s_001498.png
#  extracting: 1/test/bird/dunnock_s_001230.png
#  extracting: 1/test/bird/bird_s_002427.png
#  extracting: 1/test/bird/passerine_s_001696.png
#  extracting: 1/test/bird/prunella_modularis_s_000893.png
#  extracting: 1/test/bird/lark_s_001530.png
#   inflating: 1/test/bird/finch_s_000625.png
#  extracting: 1/test/bird/emu_s_000250.png
#   inflating: 1/test/bird/hen_s_000410.png
#  extracting: 1/test/bird/emu_s_000266.png
#  extracting: 1/test/bird/honey_eater_s_000415.png
#  extracting: 1/test/bird/accentor_s_001189.png
#  extracting: 1/test/bird/cassowary_s_001047.png
#   inflating: 1/test/bird/dunnock_s_000187.png
#  extracting: 1/test/bird/bird_s_000253.png
#  extracting: 1/test/bird/emu_s_000755.png
#  extracting: 1/test/bird/bird_s_001829.png
#  extracting: 1/test/bird/cassowary_s_000066.png
#  extracting: 1/test/bird/alauda_arvensis_s_000975.png
#  extracting: 1/test/bird/wagtail_s_000296.png
#  extracting: 1/test/bird/passerine_s_000168.png
#   inflating: 1/test/bird/pipit_s_000055.png
#  extracting: 1/test/bird/alauda_arvensis_s_000804.png
#  extracting: 1/test/bird/dunnock_s_000264.png
#  extracting: 1/test/bird/passerine_s_001324.png
#  extracting: 1/test/bird/wagtail_s_001020.png
#  extracting: 1/test/bird/prunella_modularis_s_000585.png
#   inflating: 1/test/bird/sparrow_s_001538.png
#  extracting: 1/test/bird/alauda_arvensis_s_000100.png
#   inflating: 1/test/bird/cassowary_s_000987.png
#   inflating: 1/test/bird/struthio_camelus_s_000751.png
#  extracting: 1/test/bird/pipit_s_000023.png
#  extracting: 1/test/bird/ostrich_s_000527.png
#   inflating: 1/test/bird/sparrow_s_000533.png
#  extracting: 1/test/bird/ostrich_s_000081.png
#   inflating: 1/test/bird/bird_s_001600.png
#  extracting: 1/test/bird/honey_eater_s_000329.png
#  extracting: 1/test/bird/sparrow_s_002341.png
#  extracting: 1/test/bird/cassowary_s_000463.png
#  extracting: 1/test/bird/wagtail_s_001995.png
#  extracting: 1/test/bird/wagtail_s_000953.png
#  extracting: 1/test/bird/cassowary_s_000027.png
#  extracting: 1/test/bird/alauda_arvensis_s_000615.png
#  extracting: 1/test/bird/wagtail_s_000798.png
#   inflating: 1/test/bird/dromaius_novaehollandiae_s_000183.png
#  extracting: 1/test/bird/finch_s_000310.png
#   inflating: 1/test/bird/finch_s_000765.png
#  extracting: 1/test/bird/passerine_s_001464.png
#  extracting: 1/test/bird/cassowary_s_001182.png
#  extracting: 1/test/bird/passerine_s_002042.png
#   inflating: 1/test/bird/honey_eater_s_000568.png
#  extracting: 1/test/bird/prunella_modularis_s_000906.png
#  extracting: 1/test/bird/cassowary_s_000353.png
#   inflating: 1/test/bird/finch_s_000379.png
#  extracting: 1/test/bird/cassowary_s_001530.png
#  extracting: 1/test/bird/passerine_s_001372.png
#  extracting: 1/test/bird/passerine_s_000434.png
#  extracting: 1/test/bird/passerine_s_001688.png
#   inflating: 1/test/bird/alauda_arvensis_s_000321.png
#   inflating: 1/test/bird/lark_s_000013.png
#   inflating: 1/test/bird/sparrow_s_000653.png
#  extracting: 1/test/bird/ostrich_s_001425.png
#  extracting: 1/test/bird/passerine_s_001222.png
#  extracting: 1/test/bird/ostrich_s_001286.png
#  extracting: 1/test/bird/bird_s_000336.png
#  extracting: 1/test/bird/struthio_camelus_s_001293.png
#  extracting: 1/test/bird/cassowary_s_000238.png
#  extracting: 1/test/bird/struthio_camelus_s_000264.png
#  extracting: 1/test/bird/struthio_camelus_s_001017.png
#  extracting: 1/test/bird/ostrich_s_001262.png
#  extracting: 1/test/bird/cassowary_s_002280.png
#  extracting: 1/test/bird/sparrow_s_000942.png
#  extracting: 1/test/bird/struthio_camelus_s_000626.png
#  extracting: 1/test/bird/cassowary_s_000114.png
#  extracting: 1/test/bird/pipit_s_001142.png
#  extracting: 1/test/bird/ostrich_s_001633.png
#  extracting: 1/test/bird/cassowary_s_001569.png
#  extracting: 1/test/bird/accentor_s_000325.png
#  extracting: 1/test/bird/nandu_s_000313.png
#  extracting: 1/test/bird/cassowary_s_002166.png
#   inflating: 1/test/bird/pipit_s_001446.png
#  extracting: 1/test/bird/dromaius_novaehollandiae_s_000413.png
#  extracting: 1/test/bird/meadow_pipit_s_000793.png
#  extracting: 1/test/bird/ostrich_s_002220.png
#  extracting: 1/test/bird/wagtail_s_001877.png
#  extracting: 1/test/bird/prunella_modularis_s_000872.png
#  extracting: 1/test/bird/struthio_camelus_s_000949.png
#   inflating: 1/test/bird/lark_s_001437.png
#   inflating: 1/test/bird/dunnock_s_000845.png
#  extracting: 1/test/bird/cassowary_s_000800.png
#  extracting: 1/test/bird/wagtail_s_001482.png
#  extracting: 1/test/bird/anthus_pratensis_s_000450.png
#  extracting: 1/test/bird/finch_s_000249.png
#   inflating: 1/test/bird/emu_s_002055.png
#  extracting: 1/test/bird/honey_eater_s_000554.png
#   inflating: 1/test/bird/wagtail_s_001180.png
#   inflating: 1/test/bird/kiwi_s_000028.png
#   inflating: 1/test/bird/pipit_s_000607.png
#  extracting: 1/test/bird/flying_bird_s_001114.png
#  extracting: 1/test/bird/sparrow_s_002275.png
#   inflating: 1/test/bird/cassowary_s_000558.png
#   inflating: 1/test/bird/wagtail_s_002091.png
#   inflating: 1/test/bird/cassowary_s_000653.png
#  extracting: 1/test/bird/emu_s_000397.png
#  extracting: 1/test/bird/passerine_s_001825.png
#  extracting: 1/test/bird/wagtail_s_000551.png
#  extracting: 1/test/bird/emu_s_001109.png
#  extracting: 1/test/bird/nandu_s_000011.png
#   inflating: 1/test/bird/wagtail_s_001316.png
#  extracting: 1/test/bird/passerine_s_001828.png
#  extracting: 1/test/bird/ostrich_s_001560.png
#  extracting: 1/test/bird/bird_of_passage_s_000847.png
#   inflating: 1/test/bird/nandu_s_000021.png

# %%
import os
a = '/content/1/test/aeroplane'
path, dirs, files = next(os.walk(a))
file_count = len(files)
print(file_count)
# Out:
# 500

# %%
# copy extracted files from virtual machine to google drive 

cp -r '/content/1' '/content/gdrive/MyDrive/assignment 1 COL870'
# Out:
#   File "<ipython-input-4-215d14a45ba0>", line 3
#     cp -r '/content/1' '/content/gdrive/MyDrive/assignment 1 COL870'
#                      ^
# SyntaxError: invalid syntax

# %%
import os
a = "/content/gdrive/MyDrive/assignment 1 COL870/1/val/dog"
path, dirs, files = next(os.walk(a))
file_count = len(files)
print(file_count)
# Out:
# 500

# %%
import torch, os
import torchvision
import torchvision.transforms as transforms
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize(mean=[0.5,0.5,0.5], std=[0.5, 0.5, 0.5])])


train_data_dir = "/content/1/train"

val_data_dir = "/content/1/val"
test_data_dir = "/content/1/test"
# take the dataset from the location nad transform it 
trainset = torchvision.datasets.ImageFolder(root=train_data_dir, transform=transform)
#divide the data into batches with batch_size=4
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=1)
print(len(trainset))

valnset = torchvision.datasets.ImageFolder(root= val_data_dir, transform=transform)
valloader = torch.utils.data.DataLoader(valnset, batch_size=4,
                                          shuffle=True, num_workers=1)

testset = torchvision.datasets.ImageFolder(root= test_data_dir , transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=1)
# Out:
# 25000

# %%
########################################################################
# Define a Convolution Neural Network
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Copy the neural network from the Neural Networks section before and modify it to
# take 3-channel images (instead of 1-channel images as it was defined).

import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

# <<<<<<<<<<<<<<<<<<<<< EDIT THE MODEL DEFINITION >>>>>>>>>>>>>>>>>>>>>>>>>>
# Try experimenting by changing the following:
# 1. number of feature maps in conv layer
# 2. Number of conv layers
# 3. Kernel size
# etc etc.,

num_epochs = 50        # desired number of training epochs.
learning_rate = 0.001   

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=256, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1)
        
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(in_features=256, out_features=256)
        self.fc2 = nn.Linear(in_features=256, out_features=128)
        self.fc3 = nn.Linear(in_features=128, out_features=128)
        self.fc3 = nn.Linear(in_features=128, out_features=5)
         # 5 is the number of classes here (for batch 3,4,5 out_features is 33)

    def forward(self, x): 

        x = F.relu(self.conv1(x))
        x = self.pool(x)
        
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        
        x = F.avg_pool2d(x, kernel_size=x.shape[2:])
        x = x.view(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        
        return x  

################### DO NOT EDIT THE BELOW CODE!!! #######################

net = Net()

# transfer the model to GPU
if torch.cuda.is_available():
    net = net.cuda()

########################################################################
# Define a Loss function and optimizer
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Let's use a Classification Cross-Entropy loss and SGD with momentum.

import torch.optim as optim
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)

num_params = np.sum([p.nelement() for p in net.parameters()])
print(num_params, ' parameters')

########################################################################
# Train the network
# ^^^^^^^^^^^^^^^^^^^^

def train(epoch, trainloader, optimizer, criterion,net):
    running_loss = 0.0
    correct=0
    total=0
    for i, data in enumerate(tqdm(trainloader), 0):
        # get the inputs
        inputs, labels = data
        if torch.cuda.is_available():
            inputs, labels = inputs.cuda(), labels.cuda()

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    

    print('epoch %d training loss: %.3f' %
            (epoch + 1, running_loss / (len(trainloader))))
    print('Accuracy of the network on the train images: %f %%' % (
                                    100 * correct / total))
    return (100* correct/total)

    
########################################################################
# Let us look at how the network performs on the test dataset.

def test(testloader, model):
    correct = 0
    total = 0
    with torch.no_grad():
        for data in tqdm(testloader):
            images, labels = data
            if torch.cuda.is_available():
                images, labels = images.cuda(), labels.cuda()        
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    print('Accuracy of the network on the test images: %f %%' % (
                                    100 * correct / total))
    return (100* correct/total)

#########################################################################
# get details of classes and class to index mapping in a directory
def find_classes(dir):
    classes = [d for d in os.listdir(dir) if os.path.isdir(os.path.join(dir, d))]
    classes.sort()
    class_to_idx = {classes[i]: i for i in range(len(classes))}
    return classes, class_to_idx


def classwise_test(testloader, model):
########################################################################
# class-wise accuracy

    classes, _ = find_classes(train_data_dir)
    n_class = len(classes) # number of classes

    class_correct = list(0. for i in range(n_class))
    class_total = list(0. for i in range(n_class))
    with torch.no_grad():
        for data in tqdm(testloader):
            images, labels = data
            if torch.cuda.is_available():
                images, labels = images.cuda(), labels.cuda()        
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(4):
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1

    for i in range(n_class):
        print('Accuracy of %10s : %2f %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))

print('Start Training')
os.makedirs('./models', exist_ok=True)
train_accuracies=[]
test_accuracies=[]
val_accuracies=[]

for epoch in range(num_epochs):  # loop over the dataset multiple times
    print('epoch ', epoch + 1)
    train_accuracy=train(epoch, trainloader, optimizer, criterion,net)
    train_accuracies.append(train_accuracy)
    val_accuracy=test(valloader, net)
    val_accuracies.append(val_accuracy)
    # test_accuracy=test(testloader, net)
    # test_accuracies.append(test_accuracy)
#     classwise_test(valloader, net)
    # save model checkpoint 
    torch.save(net.state_dict(), './models/model'+str(epoch)+'.pth')      

print('performing test')
test_accuracy=test(testloader, net)
classwise_test(testloader, net)

print('Finished Training')

# Saving our trained model
torch.save(net.state_dict(), './models/bestmodel.pth')
# Out:
# 838917  parameters
# Start Training
# epoch  1
# 100%|██████████| 6250/6250 [00:38<00:00, 163.89it/s]
# epoch 1 training loss: 1.417
# Accuracy of the network on the train images: 33.792000 %
# 100%|██████████| 625/625 [00:02<00:00, 209.13it/s]
# Accuracy of the network on the test images: 40.960000 %
# epoch  2
# 100%|██████████| 6250/6250 [00:37<00:00, 164.77it/s]
# epoch 2 training loss: 1.171
# Accuracy of the network on the train images: 46.684000 %
# 100%|██████████| 625/625 [00:03<00:00, 205.11it/s]
# Accuracy of the network on the test images: 51.160000 %
# epoch  3
# 100%|██████████| 6250/6250 [00:38<00:00, 162.95it/s]
# epoch 3 training loss: 1.099
# Accuracy of the network on the train images: 50.612000 %
# 100%|██████████| 625/625 [00:03<00:00, 207.99it/s]
# Accuracy of the network on the test images: 51.120000 %
# epoch  4
# 100%|██████████| 6250/6250 [00:38<00:00, 163.72it/s]
# epoch 4 training loss: 1.061
# Accuracy of the network on the train images: 52.216000 %
# 100%|██████████| 625/625 [00:02<00:00, 211.52it/s]
# Accuracy of the network on the test images: 52.080000 %
# epoch  5
# 100%|██████████| 6250/6250 [00:38<00:00, 163.76it/s]
# epoch 5 training loss: 1.023
# Accuracy of the network on the train images: 54.704000 %
# 100%|██████████| 625/625 [00:02<00:00, 209.83it/s]
# Accuracy of the network on the test images: 55.080000 %
# epoch  6
# 100%|██████████| 6250/6250 [00:37<00:00, 164.79it/s]
# epoch 6 training loss: 0.989
# Accuracy of the network on the train images: 56.492000 %
# 100%|██████████| 625/625 [00:03<00:00, 207.94it/s]
# Accuracy of the network on the test images: 57.280000 %
# epoch  7
# 100%|██████████| 6250/6250 [00:38<00:00, 164.36it/s]
# epoch 7 training loss: 0.956
# Accuracy of the network on the train images: 58.340000 %
# 100%|██████████| 625/625 [00:02<00:00, 211.33it/s]
# Accuracy of the network on the test images: 59.680000 %
# epoch  8
# 100%|██████████| 6250/6250 [00:37<00:00, 164.75it/s]
# epoch 8 training loss: 0.920
# Accuracy of the network on the train images: 60.520000 %
# 100%|██████████| 625/625 [00:02<00:00, 208.91it/s]
# Accuracy of the network on the test images: 61.720000 %
# epoch  9
# 100%|██████████| 6250/6250 [00:38<00:00, 164.27it/s]
# epoch 9 training loss: 0.886
# Accuracy of the network on the train images: 62.420000 %
# 100%|██████████| 625/625 [00:02<00:00, 211.58it/s]
# Accuracy of the network on the test images: 64.760000 %
# epoch  10
# 100%|██████████| 6250/6250 [00:37<00:00, 164.61it/s]
# epoch 10 training loss: 0.848
# Accuracy of the network on the train images: 64.448000 %
# 100%|██████████| 625/625 [00:02<00:00, 210.89it/s]
# Accuracy of the network on the test images: 62.160000 %
# epoch  11
# 100%|██████████| 6250/6250 [00:37<00:00, 164.53it/s]
# epoch 11 training loss: 0.810
# Accuracy of the network on the train images: 66.236000 %
# 100%|██████████| 625/625 [00:02<00:00, 211.35it/s]
# Accuracy of the network on the test images: 67.600000 %
# epoch  12
# 100%|██████████| 6250/6250 [00:38<00:00, 163.92it/s]
# epoch 12 training loss: 0.772
# Accuracy of the network on the train images: 68.096000 %
# 100%|██████████| 625/625 [00:02<00:00, 210.01it/s]
# Accuracy of the network on the test images: 68.880000 %
# epoch  13
# 100%|██████████| 6250/6250 [00:37<00:00, 164.75it/s]
# epoch 13 training loss: 0.737
# Accuracy of the network on the train images: 69.840000 %
# 100%|██████████| 625/625 [00:02<00:00, 211.86it/s]
# Accuracy of the network on the test images: 70.920000 %
# epoch  14
# 100%|██████████| 6250/6250 [00:37<00:00, 165.10it/s]
# epoch 14 training loss: 0.701
# Accuracy of the network on the train images: 71.440000 %
# 100%|██████████| 625/625 [00:02<00:00, 210.93it/s]
# Accuracy of the network on the test images: 73.200000 %
# epoch  15
# 100%|██████████| 6250/6250 [00:38<00:00, 163.91it/s]
# epoch 15 training loss: 0.665
# Accuracy of the network on the train images: 73.156000 %
# 100%|██████████| 625/625 [00:02<00:00, 209.29it/s]
# Accuracy of the network on the test images: 74.720000 %
# epoch  16
# 100%|██████████| 6250/6250 [00:37<00:00, 165.57it/s]
# epoch 16 training loss: 0.640
# Accuracy of the network on the train images: 74.316000 %
# 100%|██████████| 625/625 [00:03<00:00, 203.11it/s]
# Accuracy of the network on the test images: 76.000000 %
# epoch  17
# 100%|██████████| 6250/6250 [00:38<00:00, 162.88it/s]
# epoch 17 training loss: 0.603
# Accuracy of the network on the train images: 75.820000 %
# 100%|██████████| 625/625 [00:02<00:00, 211.63it/s]
# Accuracy of the network on the test images: 72.120000 %
# epoch  18
# 100%|██████████| 6250/6250 [00:37<00:00, 166.04it/s]
# epoch 18 training loss: 0.574
# Accuracy of the network on the train images: 77.028000 %
# 100%|██████████| 625/625 [00:02<00:00, 212.51it/s]
# Accuracy of the network on the test images: 76.600000 %
# epoch  19
# 100%|██████████| 6250/6250 [00:37<00:00, 164.93it/s]
# epoch 19 training loss: 0.547
# Accuracy of the network on the train images: 78.268000 %
# 100%|██████████| 625/625 [00:02<00:00, 210.48it/s]
# Accuracy of the network on the test images: 75.960000 %
# epoch  20
# 100%|██████████| 6250/6250 [00:37<00:00, 167.36it/s]
# epoch 20 training loss: 0.520
# Accuracy of the network on the train images: 79.296000 %
# 100%|██████████| 625/625 [00:02<00:00, 211.39it/s]
# Accuracy of the network on the test images: 73.880000 %
# epoch  21
# 100%|██████████| 6250/6250 [00:38<00:00, 163.93it/s]
# epoch 21 training loss: 0.497
# Accuracy of the network on the train images: 80.620000 %
# 100%|██████████| 625/625 [00:03<00:00, 208.09it/s]
# Accuracy of the network on the test images: 77.960000 %
# epoch  22
# 100%|██████████| 6250/6250 [00:38<00:00, 161.45it/s]
# epoch 22 training loss: 0.474
# Accuracy of the network on the train images: 81.660000 %
# 100%|██████████| 625/625 [00:02<00:00, 208.52it/s]
# Accuracy of the network on the test images: 78.760000 %
# epoch  23
# 100%|██████████| 6250/6250 [00:37<00:00, 165.32it/s]
# epoch 23 training loss: 0.451
# Accuracy of the network on the train images: 82.412000 %
# 100%|██████████| 625/625 [00:02<00:00, 211.62it/s]
# Accuracy of the network on the test images: 71.520000 %
# epoch  24
# 100%|██████████| 6250/6250 [00:37<00:00, 165.74it/s]
# epoch 24 training loss: 0.435
# Accuracy of the network on the train images: 83.124000 %
# 100%|██████████| 625/625 [00:02<00:00, 211.89it/s]
# Accuracy of the network on the test images: 76.920000 %
# epoch  25
# 100%|██████████| 6250/6250 [00:37<00:00, 165.16it/s]
# epoch 25 training loss: 0.414
# Accuracy of the network on the train images: 83.968000 %
# 100%|██████████| 625/625 [00:03<00:00, 208.06it/s]
# Accuracy of the network on the test images: 77.920000 %
# epoch  26
# 100%|██████████| 6250/6250 [00:38<00:00, 164.02it/s]
# epoch 26 training loss: 0.394
# Accuracy of the network on the train images: 84.640000 %
# 100%|██████████| 625/625 [00:02<00:00, 208.86it/s]
# Accuracy of the network on the test images: 76.800000 %
# epoch  27
# 100%|██████████| 6250/6250 [00:38<00:00, 162.62it/s]
# epoch 27 training loss: 0.374
# Accuracy of the network on the train images: 85.724000 %
# 100%|██████████| 625/625 [00:02<00:00, 209.72it/s]
# Accuracy of the network on the test images: 76.080000 %
# epoch  28
# 100%|██████████| 6250/6250 [00:37<00:00, 164.69it/s]
# epoch 28 training loss: 0.358
# Accuracy of the network on the train images: 86.440000 %
# 100%|██████████| 625/625 [00:02<00:00, 208.83it/s]
# Accuracy of the network on the test images: 79.560000 %
# epoch  29
# 100%|██████████| 6250/6250 [00:38<00:00, 163.96it/s]
# epoch 29 training loss: 0.347
# Accuracy of the network on the train images: 86.492000 %
# 100%|██████████| 625/625 [00:02<00:00, 209.23it/s]
# Accuracy of the network on the test images: 80.760000 %
# epoch  30
# 100%|██████████| 6250/6250 [00:38<00:00, 164.47it/s]
# epoch 30 training loss: 0.331
# Accuracy of the network on the train images: 87.284000 %
# 100%|██████████| 625/625 [00:02<00:00, 209.11it/s]
# Accuracy of the network on the test images: 80.680000 %
# epoch  31
# 100%|██████████| 6250/6250 [00:38<00:00, 164.18it/s]
# epoch 31 training loss: 0.314
# Accuracy of the network on the train images: 87.960000 %
# 100%|██████████| 625/625 [00:02<00:00, 210.35it/s]
# Accuracy of the network on the test images: 79.520000 %
# epoch  32
# 100%|██████████| 6250/6250 [00:37<00:00, 164.86it/s]
# epoch 32 training loss: 0.298
# Accuracy of the network on the train images: 88.564000 %
# 100%|██████████| 625/625 [00:02<00:00, 210.10it/s]
# Accuracy of the network on the test images: 80.080000 %
# epoch  33
# 100%|██████████| 6250/6250 [00:38<00:00, 163.22it/s]
# epoch 33 training loss: 0.281
# Accuracy of the network on the train images: 89.336000 %
# 100%|██████████| 625/625 [00:02<00:00, 209.36it/s]
# Accuracy of the network on the test images: 81.400000 %
# epoch  34
# 100%|██████████| 6250/6250 [00:38<00:00, 163.37it/s]
# epoch 34 training loss: 0.265
# Accuracy of the network on the train images: 89.788000 %
# 100%|██████████| 625/625 [00:03<00:00, 204.51it/s]
# Accuracy of the network on the test images: 77.560000 %
# epoch  35
# 100%|██████████| 6250/6250 [00:38<00:00, 163.91it/s]
# epoch 35 training loss: 0.255
# Accuracy of the network on the train images: 90.444000 %
# 100%|██████████| 625/625 [00:02<00:00, 209.22it/s]
# Accuracy of the network on the test images: 81.360000 %
# epoch  36
# 100%|██████████| 6250/6250 [00:38<00:00, 164.41it/s]
# epoch 36 training loss: 0.242
# Accuracy of the network on the train images: 90.908000 %
# 100%|██████████| 625/625 [00:03<00:00, 206.47it/s]
# Accuracy of the network on the test images: 80.840000 %
# epoch  37
# 100%|██████████| 6250/6250 [00:37<00:00, 165.01it/s]
# epoch 37 training loss: 0.230
# Accuracy of the network on the train images: 91.396000 %
# 100%|██████████| 625/625 [00:02<00:00, 208.85it/s]
# Accuracy of the network on the test images: 75.520000 %
# epoch  38
# 100%|██████████| 6250/6250 [00:37<00:00, 164.88it/s]
# epoch 38 training loss: 0.219
# Accuracy of the network on the train images: 91.736000 %
# 100%|██████████| 625/625 [00:03<00:00, 207.88it/s]
# Accuracy of the network on the test images: 79.320000 %
# epoch  39
# 100%|██████████| 6250/6250 [00:37<00:00, 164.99it/s]
# epoch 39 training loss: 0.201
# Accuracy of the network on the train images: 92.700000 %
# 100%|██████████| 625/625 [00:02<00:00, 209.75it/s]
# Accuracy of the network on the test images: 80.880000 %
# epoch  40
# 100%|██████████| 6250/6250 [00:38<00:00, 164.04it/s]
# epoch 40 training loss: 0.191
# Accuracy of the network on the train images: 92.852000 %
# 100%|██████████| 625/625 [00:03<00:00, 207.76it/s]
# Accuracy of the network on the test images: 81.000000 %
# epoch  41
# 100%|██████████| 6250/6250 [00:38<00:00, 160.48it/s]
# epoch 41 training loss: 0.182
# Accuracy of the network on the train images: 93.236000 %
# 100%|██████████| 625/625 [00:03<00:00, 207.36it/s]
# Accuracy of the network on the test images: 81.400000 %
# epoch  42
# 100%|██████████| 6250/6250 [00:38<00:00, 161.71it/s]
# epoch 42 training loss: 0.176
# Accuracy of the network on the train images: 93.412000 %
# 100%|██████████| 625/625 [00:03<00:00, 206.69it/s]
# Accuracy of the network on the test images: 80.280000 %
# epoch  43
# 100%|██████████| 6250/6250 [00:38<00:00, 162.91it/s]
# epoch 43 training loss: 0.159
# Accuracy of the network on the train images: 94.064000 %
# 100%|██████████| 625/625 [00:02<00:00, 209.58it/s]
# Accuracy of the network on the test images: 82.160000 %
# epoch  44
# 100%|██████████| 6250/6250 [00:38<00:00, 163.28it/s]
# epoch 44 training loss: 0.159
# Accuracy of the network on the train images: 94.260000 %
# 100%|██████████| 625/625 [00:03<00:00, 207.59it/s]
# Accuracy of the network on the test images: 82.720000 %
# epoch  45
# 100%|██████████| 6250/6250 [00:38<00:00, 162.81it/s]
# epoch 45 training loss: 0.145
# Accuracy of the network on the train images: 94.680000 %
# 100%|██████████| 625/625 [00:02<00:00, 208.74it/s]
# Accuracy of the network on the test images: 79.560000 %
# epoch  46
# 100%|██████████| 6250/6250 [00:38<00:00, 162.79it/s]
# epoch 46 training loss: 0.141
# Accuracy of the network on the train images: 94.840000 %
# 100%|██████████| 625/625 [00:02<00:00, 210.32it/s]
# Accuracy of the network on the test images: 75.520000 %
# epoch  47
# 100%|██████████| 6250/6250 [00:38<00:00, 163.70it/s]
# epoch 47 training loss: 0.138
# Accuracy of the network on the train images: 94.916000 %
# 100%|██████████| 625/625 [00:03<00:00, 206.85it/s]
# Accuracy of the network on the test images: 81.800000 %
# epoch  48
# 100%|██████████| 6250/6250 [00:38<00:00, 163.37it/s]
# epoch 48 training loss: 0.127
# Accuracy of the network on the train images: 95.480000 %
# 100%|██████████| 625/625 [00:02<00:00, 209.77it/s]
# Accuracy of the network on the test images: 80.560000 %
# epoch  49
# 100%|██████████| 6250/6250 [00:38<00:00, 163.27it/s]
# epoch 49 training loss: 0.116
# Accuracy of the network on the train images: 95.880000 %
# 100%|██████████| 625/625 [00:03<00:00, 205.25it/s]
# Accuracy of the network on the test images: 78.720000 %
# epoch  50
# 100%|██████████| 6250/6250 [00:38<00:00, 162.82it/s]
# epoch 50 training loss: 0.112
# Accuracy of the network on the train images: 96.040000 %
# 100%|██████████| 625/625 [00:02<00:00, 209.35it/s]
# Accuracy of the network on the test images: 82.080000 %
# performing test
# 100%|██████████| 625/625 [00:02<00:00, 208.54it/s]
# Accuracy of the network on the test images: 81.480000 %
# 100%|██████████| 625/625 [00:03<00:00, 201.38it/s]
# Accuracy of  aeroplane : 89.400000 %
# Accuracy of       bird : 88.600000 %
# Accuracy of        cat : 67.600000 %
# Accuracy of        dog : 73.000000 %
# Accuracy of       ship : 88.800000 %
# Finished Training

# %%
print(len(train_accuracies))
print(len(val_accuracies))
with open(r'trainconv3.txt', 'w') as fp:
  for item in train_accuracies:
     fp.write("%s\n" % item)
# Out:
# 50
# 50

# %%
with open(r'valconv3.txt', 'w') as fp:
  for item in val_accuracies:
     fp.write("%s\n" % item)

# %%
epochs= np.arange(0, 50, 1)
  
# Assign variables to the y axis part of the curve
y = train_accuracies
z = val_accuracies
  
# Plotting both the curves simultaneously
plt.plot(epochs, y, color='r', label='train_accuracy')
plt.plot(epochs, z, color='g', label='val_accuracy')
  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Model Accuracy")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
########################################################################
# Define a Convolution Neural Network
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Copy the neural network from the Neural Networks section before and modify it to
# take 3-channel images (instead of 1-channel images as it was defined).

import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

# <<<<<<<<<<<<<<<<<<<<< EDIT THE MODEL DEFINITION >>>>>>>>>>>>>>>>>>>>>>>>>>
# Try experimenting by changing the following:
# 1. number of feature maps in conv layer
# 2. Number of conv layers
# 3. Kernel size
# etc etc.,

num_epochs = 50        # desired number of training epochs.
learning_rate = 0.001   

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(in_features=512, out_features=256)
        self.fc2 = nn.Linear(in_features=256, out_features=128)
        
        self.fc3 = nn.Linear(in_features=128, out_features=5)
         # 5 is the number of classes here (for batch 3,4,5 out_features is 33)

    def forward(self, x): 

        x = F.relu(self.conv1(x))
        x = self.pool(x)
        
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        x = F.relu(self.conv4(x))
        x = self.pool(x)
        x = F.relu(self.conv5(x))
        x = self.pool(x)
        
        
        x = F.avg_pool2d(x, kernel_size=x.shape[2:])
        x = x.view(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        
        return x  

################### DO NOT EDIT THE BELOW CODE!!! #######################

net = Net()

# transfer the model to GPU
if torch.cuda.is_available():
    net = net.cuda()

########################################################################
# Define a Loss function and optimizer
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Let's use a Classification Cross-Entropy loss and SGD with momentum.

import torch.optim as optim
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)

num_params = np.sum([p.nelement() for p in net.parameters()])
print(num_params, ' parameters')

########################################################################
# Train the network
# ^^^^^^^^^^^^^^^^^^^^

def train(epoch, trainloader, optimizer, criterion,net):
    running_loss = 0.0
    correct=0
    total=0
    for i, data in enumerate(tqdm(trainloader), 0):
        # get the inputs
        inputs, labels = data
        if torch.cuda.is_available():
            inputs, labels = inputs.cuda(), labels.cuda()

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    

    print('epoch %d training loss: %.3f' %
            (epoch + 1, running_loss / (len(trainloader))))
    print('Accuracy of the network on the train images: %f %%' % (
                                    100 * correct / total))
    return (100* correct/total)

    
########################################################################
# Let us look at how the network performs on the test dataset.

def test(testloader, model):
    correct = 0
    total = 0
    with torch.no_grad():
        for data in tqdm(testloader):
            images, labels = data
            if torch.cuda.is_available():
                images, labels = images.cuda(), labels.cuda()        
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    print('Accuracy of the network on the test images: %f %%' % (
                                    100 * correct / total))
    return (100* correct/total)

#########################################################################
# get details of classes and class to index mapping in a directory
def find_classes(dir):
    classes = [d for d in os.listdir(dir) if os.path.isdir(os.path.join(dir, d))]
    classes.sort()
    class_to_idx = {classes[i]: i for i in range(len(classes))}
    return classes, class_to_idx


def classwise_test(testloader, model):
########################################################################
# class-wise accuracy

    classes, _ = find_classes(train_data_dir)
    n_class = len(classes) # number of classes

    class_correct = list(0. for i in range(n_class))
    class_total = list(0. for i in range(n_class))
    with torch.no_grad():
        for data in tqdm(testloader):
            images, labels = data
            if torch.cuda.is_available():
                images, labels = images.cuda(), labels.cuda()        
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(4):
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1

    for i in range(n_class):
        print('Accuracy of %10s : %2f %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))

print('Start Training')
os.makedirs('./models', exist_ok=True)
train_accuracies=[]
test_accuracies=[]
val_accuracies=[]

for epoch in range(num_epochs):  # loop over the dataset multiple times
    print('epoch ', epoch + 1)
    train_accuracy=train(epoch, trainloader, optimizer, criterion,net)
    train_accuracies.append(train_accuracy)
    val_accuracy=test(valloader, net)
    val_accuracies.append(val_accuracy)
    # test_accuracy=test(testloader, net)
    # test_accuracies.append(test_accuracy)
#     classwise_test(valloader, net)
    # save model checkpoint 
    torch.save(net.state_dict(), './models/model'+str(epoch)+'.pth')      

print('performing test')
test_accuracy=test(testloader, net)
classwise_test(testloader, net)

print('Finished Training')

# Saving our trained model
torch.save(net.state_dict(), './models/bestmodelconv5.pth')
# Out:
# 4075653  parameters
# Start Training
# epoch  1
# 100%|██████████| 6250/6250 [19:28<00:00,  5.35it/s]
# epoch 1 training loss: 1.498
# Accuracy of the network on the train images: 27.480000 %
# 100%|██████████| 625/625 [00:42<00:00, 14.73it/s]
# Accuracy of the network on the test images: 38.760000 %
# epoch  2
# 100%|██████████| 6250/6250 [19:33<00:00,  5.33it/s]
# epoch 2 training loss: 1.178
# Accuracy of the network on the train images: 45.568000 %
# 100%|██████████| 625/625 [00:40<00:00, 15.34it/s]
# Accuracy of the network on the test images: 53.160000 %
# epoch  3
# 100%|██████████| 6250/6250 [19:29<00:00,  5.34it/s]
# epoch 3 training loss: 1.022
# Accuracy of the network on the train images: 55.048000 %
#  18%|█▊        | 113/625 [00:07<00:33, 15.36it/s]
